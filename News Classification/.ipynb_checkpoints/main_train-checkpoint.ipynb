# %%
# Load the data from MongoDB and convert them to a python dictionary 
import spacy
import pymongo

# Load spaCy models
nlp_dpt = spacy.load('archive/Model_tilldpt/')
nlp = spacy.load('archive/Model_tillmainkeywords/')
nlp_ind = spacy.load('archive/Model_industry/')
nlp_company = spacy.load("en_core_web_md")

# Connect to the MongoDB server
client = pymongo.MongoClient("mongodb://Aditya:123456@20.25.72.14:27017/?authMechanism=DEFAULT&authSource=admin")

# Choose the 'news' database
db = client['news']

# Choose the 'news_set' collection
collection = db['news_set']

# Query all data and exclude the _id field
query_result = collection.find({}, {"_id": 0})

# Initialize an empty list to store the data
data_list = []

# Loop through the query result and append each document to the list
for item in query_result:
    data_list.append(item)

# Print the number of documents retrieved
print(f"Retrieved {len(data_list)} documents from 'news_set' collection")

# Close the MongoDB connection
client.close()
# Out:
# Retrieved 725555 documents from 'news_set' collection

# %%
keywords_mapkey = {
  "ExecutiveMove_flt": [
    "executive move",
    "executive hire",
    "executive promotion",
    "executive departure",
    "leadership shakeup",
    "change in senior management",
    "board of directors appointment",
    "ceo replacement",
    "cfo transition",
    "c-suite reshuffle",
    "vp hire",
    "vp resignation",
    "new hire announcement",
    "corporate restructuring",
    "management reorganization",
    "personnel changes",
    "executive compensation",
    "executive succession planning",
    "head of department appointment",
    "leadership transition"
  ],
  "HiringPlan_flt": [
    "hiring plan",
    "recruitment",
    "job openings",
    "workforce growth",
    "staffing increase",
    "human resources",
    "career opportunities",
    "workforce expansion",
    "employment opportunities",
    "new positions",
    "new hires",
    "job vacancies",
    "labor market",
    "labor force",
    "retention strategy",
    "career development",
    "talent acquisition",
    "job search",
    "job fair",
    "job hunting",
    "hiring trends"
  ],
  "LateralMove_flt": [
    "lateral move",
    "job change",
    "job transition",
    "job shifting",
    "inter-departmental transfer",
    "job promotion",
    "job rotation",
    "internal hiring",
    "inter-company transfer",
    "job changing",
    "career transition",
    "role mobility",
    "role shifting",
    "vertical move",
    "career advancement",
    "job transfer",
    "job relocation",
    "job reassignment",
    "career shift",
    "job switching"
  ],
  "Layoffs_flt": [
    "layoffs",
    "job cuts",
    "downsizing",
    "restructuring",
    "rif",
    "furloughs",
    "forced retirement",
    "early retirement",
    "terminations",
    "right-sizing",
    "workforce reduction",
    "letting go",
    "dismissal",
    "reduction in force",
    "downsizing of employees",
    "reduced hours",
    "pay cuts",
    "pay reduction"
  ],
  "LeftCompany_flt": [
    "left company",
    "resigned",
    "retired",
    "terminated",
    "stepped down",
    "ceased employment",
    "left role",
    "fired",
    "dismissed",
    "laid off",
    "let go",
    "forced out",
    "ousted",
    "vacated",
    "retiredfrom",
    "withdrew from"
  ],
  "ManagementMove_flt": [
    "management move",
    "leadership change",
    "c-suite reshuffle",
    "management restructuring",
    "reorganization",
    "executive promotion",
    "boardroom shake-up",
    "reallocation of resources",
    "shift in strategy",
    "corporate governance",
    "new direction",
    "downsizing",
    "upsizing",
    "redeployment of personnel",
    "resignation",
    "hiring",
    "firing",
    "merger",
    "acquisition",
    "divestiture"
  ],
  "Openpositions_flt": [
    "open positions",
    "job openings",
    "career opportunities",
    "hiring",
    "recruiting",
    "employment",
    "staffing",
    "vacancies",
    "new jobs",
    "work opportunities",
    "placements",
    "jobs available",
    "organizational openings",
    "work openings",
    "job search",
    "job market",
    "job postings",
    "job fairs",
    "resumes",
    "applications",
    "interviews",
    "hiring process",
    "candidate selection",
    "career advancement",
    "careers",
    "career advice"
  ],
  "Promotion_flt": [
    "promotion",
    "salary increase",
    "career move",
    "career change",
    "career development",
    "career growth",
    "level up",
    "position change",
    "job promotion",
    "job title change",
    "job grade change",
    "promoted",
    "promotee"
  ],
  "Divestiture_flt": [
    "divestiture",
    "divestment",
    "split-off",
    "carve-out",
    "spin-off",
    "asset sale",
    "divest",
    "divesting",
    "unbundled",
    "unbundling",
    "selling assets",
    "selloff",
    "acquisition",
    "merger",
    "joint venture",
    "divisionalization"
  ],
  "Earningsreport_flt": [
    "earnings report",
    "eps",
    "net income",
    "operating income",
    "operating margin",
    "gross profit",
    "gross margin",
    "diluted eps",
    "shareholder dividends",
    "earnings per share",
    "quarterly earnings",
    "yearly results",
    "earnings conference call",
    "financial statements",
    "earnings forecast",
    "ebitda",
    "ebit",
    "net profit",
    "cash flow",
    "return on equity",
    "return on assets"
  ],
  "Funding_flt": [
    "funding",
    "venture capital",
    "seed funding",
    "angel investment",
    "private equity",
    "investor",
    "ipo",
    "series a round",
    "series b round",
    "series c round",
    "acquisition",
    "merger",
    "m&a",
    "debt financing",
    "equity financing"
  ],
  "IPO_flt": [
    "ipo",
    "initial public offering",
    "new issue",
    "underwriter",
    "brokerage",
    "securities exchange commission",
    "bookrunner",
    "trading",
    "stock exchange",
    "market capitalization",
    "shareholder",
    "offering price",
    "underpricing",
    "overpricing",
    "lock-up period",
    "lockup agreement",
    "prospectus",
    "shelf registration",
    "direct public offering",
    "reverse merger",
    "reverse ipo",
    "going public",
    "ipo roadshow"
  ],
  "M&A_flt": [
    "m&a",
    "mergers & acquisitions",
    "acquisition",
    "divestiture",
    "consolidation",
    "joint venture",
    "strategic alliance",
    "shareholder value",
    "hostile bid",
    "company acquisition",
    "asset purchase",
    "stock swap",
    "going private",
    "going public",
    "spin-off",
    "reverse merger"
  ],
  "Award_flt": [
    "award",
    "business award",
    "award recipient",
    "award ceremony",
    "award winning",
    "business accolade",
    "business recognition",
    "awarded business",
    "awarded service",
    "awarded product",
    "awarded innovation",
    "awarded quality",
    "awarded excellence",
    "awarded initiative",
    "awarded performance",
    "awarded achievement",
    "awarded leadership",
    "awarded success",
    "awarded recognition",
    "awarded honor",
    "awarded distinction",
    "awarded honor roll",
    "awarded merit",
    "awarded achiever",
    "awarded distinction",
    "awarded excellence",
    "awarded recognition",
    "awarded commendation",
    "awarded appreciation",
    "awarded top prize",
    "awarded best in show",
    "awarded grand prize",
    "awarded prize winner",
    "awarded industry leader",
    "awarded industry award"
  ],
  "revenuegrowth_flt": [
    "revenue growth",
    "financial results",
    "stock market",
    "m&a",
    "ipo",
    "merger",
    "acquisition",
    "restructuring",
    "investment",
    "dividend",
    "earnings call",
    "debt reduction",
    "corporate governance",
    "stock buyback",
    "product launch",
    "alliances",
    "strategic alliance",
    "strategic partnership",
    "strategic investments",
    "corporate strategies",
    "market strategies",
    "market share",
    "corporate restructuring",
    "cost cutting",
    "operational efficiency",
    "employee engagement",
    "customer satisfaction",
    "marketing campaigns",
    "innovation",
    "new products",
    "business expansion",
    "supply chain"
  ],
  "FacilitiesRelocation_flt": [
    "facilities relocation",
    "facilities expansion",
    "relocation",
    "relocation of facilities",
    "expansion of facilities",
    "business relocation",
    "business expansion",
    "corporate relocation",
    "corporate expansion",
    "facility move",
    "facility relocation",
    "business move",
    "commercial relocation",
    "commercial expansion",
    "business relocation services",
    "business expansion services",
    "space relocation",
    "space expansion"
  ],
  "Alliance_flt": [
    "alliance",
    "joint venture",
    "strategic collaboration",
    "joint development",
    "co-marketing",
    "joint research",
    "co-working",
    "co-branding",
    "mutual benefits",
    "shared resources",
    "shared goals",
    "team-up",
    "collaborative effort",
    "pooled resources",
    "co-operation",
    "co-creation",
    "merger",
    "acquisition"
  ],
  "ProductLaunch_flt": [
    "product launch",
    "launch event",
    "product rollout",
    "new product",
    "product introduction",
    "product unveiling",
    "product release",
    "product debut",
    "product reveal",
    "product demo",
    "product showcase",
    "product demo day",
    "product release date",
    "launch date",
    "product launch strategy",
    "launch plan",
    "market launch"
  ],
  "Painpoints_flt": [
    "pain points",
    "business challenges",
    "cost optimization",
    "productivity improvement",
    "process automation",
    "efficiency gains",
    "operational risk management",
    "data-driven decision-making",
    "resource allocation",
    "cross-functional collaboration",
    "workflow optimization",
    "technology adoption",
    "customer experience optimization",
    "agile transformation",
    "crisis management",
    "innovation strategy",
    "strategic planning",
    "employee engagement",
    "change management",
    "risk mitigation"
  ],
  "projectmanagement_flt": [
    "project management",
    "enterprise resource planning (erp)",
    "agile methodology",
    "scrum",
    "kanban",
    "business process management (bpm)",
    "quality assurance (qa)",
    "project planning",
    "project scheduling",
    "cost analysis",
    "task management",
    "risk analysis",
    "change management",
    "business analysis",
    "process optimization",
    "data analysis",
    "business intelligence",
    "strategic planning",
    "strategic execution",
    "strategy implementation",
    "project governance",
    "stakeholder management",
    "resource allocation",
    "process automation",
    "data integration"
  ],
  "Startups_flt": [
    "startups",
    "startup",
    "start-up",
    "incubator",
    "accelerator",
    "venture capital",
    "angel investor",
    "seed funding",
    "ipo",
    "unicorn",
    "disruptive technology",
    "innovative company",
    "entrepreneur",
    "innovator",
    "crowdfunding",
    "pivot"
  ]
}

# %%
# In[8]: Converting the Dataset to format on which SpaCy NER model trains

nlpe = spacy.load('en_core_web_sm')

# Add entity labels to the NER model
ner = nlpe.get_pipe("ner")
for entity, keywords_list in keywords_mapkey.items():
    ner.add_label(entity)

# Initialize the training data
TRAIN_DATA = []

# Function to find entities in the text and label them
def label_entities(text, keywords):
    entities = []
    words = text.split()  # Split the text into words
    for entity, keywords_list in keywords.items():
        for keyword in keywords_list:
            for word in words:
                if word.lower() == keyword.lower():  # Check for a whole word match
                    start = text.find(word)
                    end = start + len(word)
                    entities.append((start, end, entity))
    return entities

# Generate training data for the first 1000 news headlines
for item in data_list[:10000]:
    if 'news' in item and 'head' in item['news']:
        text = item['news']['head']
        entities = label_entities(text, keywords_mapkey)
        if entities:
            # Sort entities by start position to avoid overlap
            entities.sort(key=lambda x: x[0])
            # Only label the first entity found
            TRAIN_DATA.append((text, {'entities': entities[:1]}))

print(f"the length of TRAIN_DATA is {len(TRAIN_DATA)} ")
# Out:
# the length of TRAIN_DATA is 1172

# %%
TRAIN_DATA
# Out:
# [('First Responder Technologies Commences Trading on the OTCQB Market in the United States',
#   {'entities': [(39, 46, 'IPO_flt')]}),
#  ('Kayentis raised €7M in growth funding backed by Extens and LBO France with participation from new backer Bpifrance.',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('ABL Bio raised ₩20,000,000,000 / Series B from DSC Investment and 3 other investors',
#   {'entities': [(51, 61, 'revenuegrowth_flt')]}),
#  ('ABL Bio raised ₩9,000,000,000 / Series A from DSC Investment and HantuPa',
#   {'entities': [(50, 60, 'revenuegrowth_flt')]}),
#  ('New Accelerator Is On A Mission To Turn NYC Into A Hub For Healthtech&nbsp;Startups',
#   {'entities': [(4, 15, 'Startups_flt')]}),
#  ('3 health tech startups to watch from the DC to VC showcase',
#   {'entities': [(14, 22, 'Startups_flt')]}),
#  ('Meet health tech accelerator Blueprint Health’s latest class of startups',
#   {'entities': [(17, 28, 'Startups_flt')]}),
#  ('101 Top Health Care Startups and Companies in Toronto (2021)',
#   {'entities': [(20, 28, 'Startups_flt')]}),
#  ('Top mHealth (Mobile Health) Companies and Startups in Toronto (2021)',
#   {'entities': [(42, 50, 'Startups_flt')]}),
#  ('8 Canadian startups on the frontlines of remote medicine - MaRS Discovery District',
#   {'entities': [(11, 19, 'Startups_flt')]}),
#  ('Prism Clinical Research raised $7,000,000 / funding round',
#   {'entities': [(44, 51, 'Funding_flt')]}),
#  ('Filics raised an undisclosed amount / funding round from Elokon Ventures and Initiative for Industrial Innovators',
#   {'entities': [(38, 45, 'Funding_flt')]}),
#  ('Inter Pipeline raised $1,250,000,000 / Post Ipo Debt',
#   {'entities': [(44, 47, 'Funding_flt')]}),
#  ('Brookfield Infrastructure closes acquisition of Inter Pipeline',
#   {'entities': [(33, 44, 'ManagementMove_flt')]}),
#  ('Brookfield Infrastructure and Inter Pipeline Announce Subsequent Acquisition Transaction and Completion of Offer',
#   {'entities': [(65, 76, 'ManagementMove_flt')]}),
#  ('Female lead tech startup launches new ad platform which simplifies online advertising',
#   {'entities': [(17, 24, 'Startups_flt')]}),
#  ('MindAhead raised €500,000 / Pre Seed from AC75 Startup Accelerator and 8 other investors',
#   {'entities': [(47, 54, 'Startups_flt')]}),
#  ('The biggest unicorn in Europe', {'entities': [(12, 19, 'Startups_flt')]}),
#  ('SK Capital makes strategic investment in Lacerta Group',
#   {'entities': [(27, 37, 'revenuegrowth_flt')]}),
#  ('LACERA hiring investment officer to oversee secondaries, co-investments',
#   {'entities': [(7, 13, 'ManagementMove_flt')]}),
#  ('Sarepta Therapeutics Signs Long-term Strategic Investment and License Agreements with Lacerta Therapeutics, Gaining Rights to Multiple CNS-targeted Gene Therapy programs and Access to Important Gene Therapy Talent and Tools',
#   {'entities': [(47, 57, 'revenuegrowth_flt')]}),
#  ('Dutch startup Fusion Engineering raises €700K to build flight controllers for the commercial drone market',
#   {'entities': [(6, 13, 'Startups_flt')]}),
#  ('Fusion Engineering raised €700,000 / Pre Seed from Graduate Entrepreneur Fund',
#   {'entities': [(60, 72, 'Startups_flt')]}),
#  ('That’s sweet: Durham food tech startup Elo Life Systems lands $24.5M',
#   {'entities': [(31, 38, 'Startups_flt')]}),
#  ('Hylan Datacom & Electrical Announces Significant Investment by Flexis Capital and TZP Group',
#   {'entities': [(49, 59, 'revenuegrowth_flt')]}),
#  ('Nigerian fintech startup Payhippo raised $1m pre-seed funding',
#   {'entities': [(17, 24, 'Startups_flt')]}),
#  ('Selected for Plug and Play’s Accelerator Program',
#   {'entities': [(29, 40, 'Startups_flt')]}),
#  ('Tech Jobs: These Recently Funded Robotics Startups Are Hiring Humans',
#   {'entities': [(42, 50, 'Startups_flt')]}),
#  ('Take This Job And Automate It: Startups Tackling Labor Shortages Draw More VC Interest',
#   {'entities': [(31, 39, 'Startups_flt')]}),
#  ('What This Year’s Seed Funding Tells Us About The Startup Future',
#   {'entities': [(22, 29, 'Funding_flt')]}),
#  ('These 10 Russian startups are pitching at TechCrunch Disrupt next week',
#   {'entities': [(17, 25, 'Startups_flt')]}),
#  ('Russian tech startups set their sights on the New World',
#   {'entities': [(13, 21, 'Startups_flt')]}),
#  ('Navigine: Startup Accelerator Holds Innovation Review at Henry Mayo Hospital',
#   {'entities': [(10, 17, 'Startups_flt')]}),
#  ('Fusionex Wins Channel Asia Innovation Awards 2021 for the Homegrown Independent Software Vendor Category',
#   {'entities': [(27, 37, 'revenuegrowth_flt')]}),
#  ('Second-Time Unlucky: Interswitch Forced To Further Delay IPO Until 2021',
#   {'entities': [(57, 60, 'Funding_flt')]}),
#  ('Nigerian startup, Paga raises $10 million as foreign investors continue to bet on FinTech startups',
#   {'entities': [(90, 98, 'Startups_flt')]}),
#  ('Nigerian fintech Paga raises $10m in round led by Global Innovation Fund',
#   {'entities': [(57, 67, 'revenuegrowth_flt')]}),
#  ('Interswitch allegedly on the path to UK IPO',
#   {'entities': [(40, 43, 'Funding_flt')]}),
#  ('Nigerian Fintech Company Interswitch Could Become Africa’s First Public Startup Unicorn',
#   {'entities': [(72, 79, 'Startups_flt')]}),
#  ('Nigeria’s top 5 startup moments of 2015',
#   {'entities': [(16, 23, 'Startups_flt')]}),
#  ('The year of mobile? 9 of Africa’s most exciting startup investments of 2015',
#   {'entities': [(48, 55, 'Startups_flt')]}),
#  ('Funding roundup: FirstRide, Nanobi, Cubito and PropTiger',
#   {'entities': [(0, 7, 'Funding_flt')]}),
#  ('Excl: Online platform to book car test drives FirstRide gets angel funding | Techcircle.in - India startups, internet, mobile, e-commerce, software, online businesses, technology, venture capital, angel, seed funding',
#   {'entities': [(67, 74, 'Funding_flt')]}),
#  ('Space traffic analytics startup Kayhan Space raises $3.7 million in seed funding',
#   {'entities': [(24, 31, 'Startups_flt')]}),
#  ('Former Commerce official Kevin O’Connell joins board of advisors of startup Kayhan Space',
#   {'entities': [(68, 75, 'Startups_flt')]}),
#  ('Startup Kayhan Space Is Working To Keep Satellites Safer From Space Junk',
#   {'entities': [(0, 7, 'Startups_flt')]}),
#  ('Denver startup Kayhan Space lands $600K seed round for collision avoidance software',
#   {'entities': [(7, 14, 'Startups_flt')]}),
#  ('Pollen Mobile Closes Seed Funding Round',
#   {'entities': [(26, 33, 'Funding_flt')]}),
#  ('Pollen Mobile Closes Seed Funding Round for Its Next-Generation Decentralized Wireless Network',
#   {'entities': [(26, 33, 'Funding_flt')]}),
#  ('EcoSwarm raised $40,000 / Seed from Start-Up Chile',
#   {'entities': [(36, 44, 'Startups_flt')]}),
#  ('Fusion Farms & i3 Acquisition Sign JV For US Expansion',
#   {'entities': [(18, 29, 'ManagementMove_flt')]}),
#  ('Fusion Farms raised $158,452 / Equity Crowdfunding',
#   {'entities': [(38, 50, 'Startups_flt')]}),
#  ('Fusion Finance Tech raised CN¥50,000,000 / Series Unknown from Zhongji Investment',
#   {'entities': [(71, 81, 'revenuegrowth_flt')]}),
#  ('Inland Investments Selects AIX Platform to Power End-to-End Digital Processing of Alternative Investment Offerings',
#   {'entities': [(7, 17, 'revenuegrowth_flt')]}),
#  ('Inland Real Estate Investment Corp. Chooses Alternative Investment Exchange as Its Digital Platform Provider',
#   {'entities': [(19, 29, 'revenuegrowth_flt')]}),
#  ('Real-time sportsbet startup Picklive cashes in its chips',
#   {'entities': [(20, 27, 'Startups_flt')]}),
#  ('Startups Discuss Working on Christmas Day',
#   {'entities': [(0, 8, 'Startups_flt')]}),
#  ('Social Sports Gaming Startup Picklive Closes Seed&nbsp;Funding',
#   {'entities': [(21, 28, 'Startups_flt')]}),
#  ('Debevoise Advises Smartly.io in its Acquisition of Ad-Lib.io',
#   {'entities': [(36, 47, 'ManagementMove_flt')]}),
#  ('Best Tech Startups in Seattle, Ranked',
#   {'entities': [(10, 18, 'Startups_flt')]}),
#  ("Innovator of the Month: Pollen Systems wants its drones to be wineries' eyes in the skies (Video)",
#   {'entities': [(0, 9, 'Startups_flt')]}),
#  ('Elonics raised $4,000,000 / Series A from Braveheart Investment Group',
#   {'entities': [(53, 63, 'revenuegrowth_flt')]}),
#  ('Helbiz Completes Acquisition of MiMoto to Add E-Mopeds to Its Innovative Fleet of Micro-Mobility Vehicles',
#   {'entities': [(17, 28, 'ManagementMove_flt')]}),
#  ('The Year’s 10 Biggest VC Funding Rounds: Epic Games Lands Epic Round, SpaceX Soars',
#   {'entities': [(25, 32, 'Funding_flt')]}),
#  ('Cloud-Security Startup Lacework Taps New CFO as It Weighs IPO',
#   {'entities': [(15, 22, 'Startups_flt')]}),
#  ("Lacework Named to CNBC's 2022 Top Startups for the Enterprise",
#   {'entities': [(34, 42, 'Startups_flt')]}),
#  ('ImageMoverMD Raises $4M in Funding',
#   {'entities': [(27, 34, 'Funding_flt')]}),
#  ('Ground-breaking edtech app miMove wins prestigious West Midlands Tech Award',
#   {'entities': [(70, 75, 'Award_flt')]}),
#  ('Innovative edtech app miMove named as award finalist',
#   {'entities': [(38, 43, 'Award_flt')]}),
#  ('Fusion Fintrade raised CN¥3,000,000 / Angel from Shanghai Xiyuxiang Investment and Sunsea IoT',
#   {'entities': [(68, 78, 'revenuegrowth_flt')]}),
#  ('TzxStar raised CN¥50,000,000 / funding round from Fusion Fintrade',
#   {'entities': [(31, 38, 'Funding_flt')]}),
#  ("Houston's Startup Ecosystem on National Stage in September",
#   {'entities': [(10, 17, 'Startups_flt')]}),
#  ('Z-Wave Alliance Releases 2022 State of the Ecosystem Report',
#   {'entities': [(7, 15, 'Alliance_flt')]}),
#  ('Top AI startup news of the week: Jasper, Tome, Imagen AI and more',
#   {'entities': [(7, 14, 'Startups_flt')]}),
#  ('ImagenAI Raises $30M in Funding', {'entities': [(24, 31, 'Funding_flt')]}),
#  ('Imagen raised £6,500,000 / Series B from Cambridge Innovation Capital and 2 other investors',
#   {'entities': [(51, 61, 'revenuegrowth_flt')]}),
#  ('Imagen raised £2,500,000 / Series Unknown from Cambridge Innovation Capital',
#   {'entities': [(57, 67, 'revenuegrowth_flt')]}),
#  ('Fusion Folder raised an undisclosed amount / Non Equity Assistance from ASU Venture Devils and Edson Student Entrepreneur Initiative',
#   {'entities': [(109, 121, 'Startups_flt')]}),
#  ('FirstRoot raised $624,484 / Equity Crowdfunding from Mirza Canada',
#   {'entities': [(35, 47, 'Startups_flt')]}),
#  ('Ask-AI raised $9,000,000 / Seed from Alliance Global Partners and 16 other investors',
#   {'entities': [(37, 45, 'Alliance_flt')]}),
#  ('Kayko raised $10,000 / Grant from Co-Creation Hub Nigeria',
#   {'entities': [(34, 45, 'Alliance_flt')]}),
#  ('30 startups in Asia that caught our eye',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('A comprehensive look at Vietnam’s startup ecosystem in 2014: 6 investors, 10 incubators, and lots more',
#   {'entities': [(34, 41, 'Startups_flt')]}),
#  ('14 Startups in Asia That Caught Our Eye',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('Kleii, Vietnam’s Dropbox, Closes First Round Of Seed Funding',
#   {'entities': [(53, 60, 'Funding_flt')]}),
#  ('13 Startups in Asia That Caught Our Eye',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('Vietnam Pitch Event Features 11 Fresh New Startups',
#   {'entities': [(42, 50, 'Startups_flt')]}),
#  ('Kleiderly raised an undisclosed amount / Non Equity Assistance from Google for Startups',
#   {'entities': [(79, 87, 'Startups_flt')]}),
#  ('Innovative Industrial Raises Funding for Pennsylvania Asset',
#   {'entities': [(29, 36, 'Funding_flt')]}),
#  ('Why cannabis businesses are hiring former politicians and regulators to move the industry’s lobbying efforts ahead',
#   {'entities': [(28, 34, 'ManagementMove_flt')]}),
#  ('Greenleaf Power Finalizes Acquisition of Plainfield Renewable Energy Power Plant in Connecticut | Business Wire',
#   {'entities': [(26, 37, 'ManagementMove_flt')]}),
#  ('Aidoc Raises $110M in Series D Funding',
#   {'entities': [(31, 38, 'Funding_flt')]}),
#  ('Aidoc nearly doubles funding with $110M haul for CT scan-reading AI',
#   {'entities': [(21, 28, 'Funding_flt')]}),
#  ('Startups unite to rebuild SL, set up platform to collect $100k for victims',
#   {'entities': [(0, 8, 'Startups_flt')]}),
#  ('Pickme, la start-up qui transforme vos voisins en relais colis',
#   {'entities': [(11, 19, 'Startups_flt')]}),
#  ('pickmebus: Google Developers Summit Buenos Aires 18 Marzo | Startups',
#   {'entities': [(60, 68, 'Startups_flt')]}),
#  ('pickmebus: 8 Awesome Argentinian Startups - Web Summit Blog',
#   {'entities': [(33, 41, 'Startups_flt')]}),
#  ('Fusion Fuel Shares Rise 12% After EUR36 Million in Grant Funding',
#   {'entities': [(57, 64, 'Funding_flt')]}),
#  ('Fusion Fuel Green Hosts Second Quarter 2022 Investor Update',
#   {'entities': [(44, 52, 'Funding_flt')]}),
#  ('Fusion Fuel Green Stock Gains After Q4 Investor Update',
#   {'entities': [(39, 47, 'Funding_flt')]}),
#  ('Fusion Fuel Green Gets Approval For €4.3M In POSEUR Funding For HEVO-Sul Project',
#   {'entities': [(52, 59, 'Funding_flt')]}),
#  ('Singapore start-up secures $12.3 billion in assets for blockchain platform',
#   {'entities': [(10, 18, 'Startups_flt')]}),
#  ('Twitter raised $2,890,000,000 / Post Ipo Equity from Elon Musk Revocable Trust',
#   {'entities': [(37, 40, 'Funding_flt')]}),
#  ('Music Factory raised an undisclosed amount / Equity Crowdfunding',
#   {'entities': [(52, 64, 'Startups_flt')]}),
#  ('What Katerra’s Collapse Means For Construction Tech Investment',
#   {'entities': [(52, 62, 'revenuegrowth_flt')]}),
#  ('Interplay Learning Raises $18 Million in Series B Funding Following 300% Growth on Year-Over-Year Sales',
#   {'entities': [(50, 57, 'Funding_flt')]}),
#  ('NaviHealth trades hands again with Optum acquisition',
#   {'entities': [(41, 52, 'ManagementMove_flt')]}),
#  ('Yonder & Beyond Group Ltd (ASX:YNB) CEO Reaffirms Commitment to Company With $1m Investment',
#   {'entities': [(81, 91, 'revenuegrowth_flt')]}),
#  ('Germany’s launch startups race to grow their launch manifests',
#   {'entities': [(17, 25, 'Startups_flt')]}),
#  ('Klein Finance Announced the Completion of a Funding Round With Participation From KCC Chain and KuCoin-Ventures',
#   {'entities': [(44, 51, 'Funding_flt')]}),
#  ('Elon University debuts new buildings for engineering, STEM and innovation (PHOTOS)',
#   {'entities': [(63, 73, 'revenuegrowth_flt')]}),
#  ('AI Startup Navikenz Secures $4 Mn In Seed Funding To Expand In India & The US',
#   {'entities': [(3, 10, 'Startups_flt')]}),
#  ('AI consulting company Navikenz raises $4 million in funding',
#   {'entities': [(52, 59, 'Funding_flt')]}),
#  ('NTT Data Beefs Up Cloud Native App Dev With Nexient Acquisition',
#   {'entities': [(52, 63, 'ManagementMove_flt')]}),
#  ('Tech firm Nexient hiring 100 new workers in Ann Arbor',
#   {'entities': [(18, 24, 'ManagementMove_flt')]}),
#  ('Ad Tech Independence in Germany Brings Challenges: Q&A with Trading Desk, Adlicious',
#   {'entities': [(60, 67, 'IPO_flt')]}),
#  ('Pearl Capital Partners raised a new fund: Yield Uganda Investment Fund (€12,000,000)',
#   {'entities': [(55, 65, 'revenuegrowth_flt')]}),
#  ('PickMyAd raised ₹2,000,000 / Pre Seed from Startup India Seed Fund Scheme',
#   {'entities': [(43, 50, 'Startups_flt')]}),
#  ('Eloops Raises $2M in Seed Funding',
#   {'entities': [(26, 33, 'Funding_flt')]}),
#  ('Microsoft Picks Israeli Startup Eloops For New Collaboration',
#   {'entities': [(24, 31, 'Startups_flt')]}),
#  ('Israeli startup Eloops launches game-from-home tool to help HR reignite company culture',
#   {'entities': [(8, 15, 'Startups_flt')]}),
#  ('Austrian car-sharing startup Eloop releases a tokenized Tesla Model 3',
#   {'entities': [(21, 28, 'Startups_flt')]}),
#  ('Old National laying off 83 Minnesota workers after Klein merger',
#   {'entities': [(57, 63, 'ManagementMove_flt')]}),
#  ('Cleantech Investment Roundup: There’s Still Life in This Turbulent Sector',
#   {'entities': [(10, 20, 'revenuegrowth_flt')]}),
#  ('Nexign Wins the MEA Business Technology Award for Nexign Revenue Management',
#   {'entities': [(40, 45, 'Award_flt')]}),
#  ('Start-up PickMyWork says will take up 500,000 gig workers in FY23',
#   {'entities': [(0, 8, 'Startups_flt')]}),
#  ('elopage Raises USD38M in Series A Funding',
#   {'entities': [(34, 41, 'Funding_flt')]}),
#  ('Elopak raised an undisclosed amount / funding round from CVC Capital Partners and Ferd',
#   {'entities': [(38, 45, 'Funding_flt')]}),
#  ('Larry Ellison Invests in Imagene AI Israeli Startup',
#   {'entities': [(44, 51, 'Startups_flt')]}),
#  ('What’s in your genes? Local start-up offers testing on wellness traits',
#   {'entities': [(28, 36, 'Startups_flt')]}),
#  ('Kaymbu raised an undisclosed amount / Series Unknown from LearnLaunch Fund + Accelerator',
#   {'entities': [(77, 88, 'Startups_flt')]}),
#  ('La Charline raised an undisclosed amount / Equity Crowdfunding',
#   {'entities': [(50, 62, 'Startups_flt')]}),
#  ('Adline raised NOK5,221,485 / Series A from Altitude Capital and Simula Innovation',
#   {'entities': [(71, 81, 'revenuegrowth_flt')]}),
#  ('Adline raised NOK3,000,000 / Debt Financing from Innovation Norway',
#   {'entities': [(49, 59, 'revenuegrowth_flt')]}),
#  ('Adline raised NOK5,774,284 / Seed from Altitude Capital and Simula Innovation',
#   {'entities': [(67, 77, 'revenuegrowth_flt')]}),
#  ('Youmi raised CN¥250,000,000 / Post Ipo Equity from Credit Prosperity Fund and 17 other investors',
#   {'entities': [(35, 38, 'Funding_flt')]}),
#  ('Linloong raised CN¥61,000,200 / Post Ipo Equity from Dipu Investment and 4 other investors',
#   {'entities': [(37, 40, 'Funding_flt')]}),
#  ('Xibei Youmian Cun raised CN¥3,000,000 / Angel from First Seafront Fund and Sapphire Lake Investment',
#   {'entities': [(89, 99, 'revenuegrowth_flt')]}),
#  ('SUNDATA raised CN¥110,000,000 / Post Ipo Equity from Broad Resources and 8 other investors',
#   {'entities': [(37, 40, 'Funding_flt')]}),
#  ('Yang Liping Tech raised CN¥50,000,000 / Post Ipo Equity from Benyu Investment and 21 other investors',
#   {'entities': [(45, 48, 'Funding_flt')]}),
#  ('LEADTHING raised CN¥39,000,000 / Post Ipo Equity from Bestar Consultant and 5 other investors',
#   {'entities': [(38, 41, 'Funding_flt')]}),
#  ('UNIFLY raised CN¥43,260,000 / Post Ipo Equity from Caitong Fund Management Co. and 5 other investors',
#   {'entities': [(35, 38, 'Funding_flt')]}),
#  ('Navily raised €1,000,000 / Series Unknown from Courtin Investment and 5 other investors',
#   {'entities': [(55, 65, 'revenuegrowth_flt')]}),
#  ('AiDot officially Joins the Connectivity Standards Alliance',
#   {'entities': [(50, 58, 'Alliance_flt')]}),
#  ('This Startup Is Tackling One of the Biggest Challenges in Robotics',
#   {'entities': [(5, 12, 'Startups_flt')]}),
#  ('Pick n Pay Reaps Big Despite Difficult Trading Environment',
#   {'entities': [(39, 46, 'IPO_flt')]}),
#  ('ImageNet expands IT services with local acquisition',
#   {'entities': [(40, 51, 'ManagementMove_flt')]}),
#  ('GeoIQ.io raised $2,250,000 / Seed from 9Unicorns Accelerator Fund and 9 other investors',
#   {'entities': [(49, 60, 'Startups_flt')]}),
#  ('StackBox gets $1.2-million funding from Ecosystem Ventures, others',
#   {'entities': [(27, 34, 'Funding_flt')]}),
#  ('Havmor ex-promoter leads Lo! Foods round; IP Ventures leads AnKa SumMor funding',
#   {'entities': [(72, 79, 'Funding_flt')]}),
#  ('Forstrong Global Asset Management acquires Shaunessy Investment Counsel',
#   {'entities': [(53, 63, 'revenuegrowth_flt')]}),
#  ('Forstrong Global Asset Management acquired Shaunessy Investment Counsel for an undisclosed amount',
#   {'entities': [(53, 63, 'revenuegrowth_flt')]}),
#  ('Techstars Music names 10 startups for its 2022 cohort',
#   {'entities': [(25, 33, 'Startups_flt')]}),
#  ('Could one of these startups become the new TikTok or SoundCloud?',
#   {'entities': [(19, 27, 'Startups_flt')]}),
#  ('Currax Pharmaceuticals Announces the Appointment of Ed Cinca to Senior Vice President, Global Marketing and Strategic Alliance Management',
#   {'entities': [(118, 126, 'Alliance_flt')]}),
#  ('RiskLens raised $1,250,000 / Series Unknown from Alliance of Angels and 3 other investors',
#   {'entities': [(49, 57, 'Alliance_flt')]}),
#  ('SpaceTech startup ConstellR, that can monitor land surface temperatures, raises €1M pre-seed round',
#   {'entities': [(10, 17, 'Startups_flt')]}),
#  ('LEVY: Study says LTC homes have huge staffing issues',
#   {'entities': [(37, 45, 'Openpositions_flt')]}),
#  ('Eloquant Receives Minority Investment from Ardian',
#   {'entities': [(27, 37, 'revenuegrowth_flt')]}),
#  ('EloQ Communications’ MD Clāra Ly-Le Named to PRovoke Media’s Innovator 25 APAC',
#   {'entities': [(61, 70, 'Startups_flt')]}),
#  ('Best Startup Asia Names EloQ Communications Among the Top Social Media Marketing Companies and Startups in the Southeast Asia',
#   {'entities': [(5, 12, 'Startups_flt')]}),
#  ('Best Startup Asia names EloQ Communications among the top social media marketing companies and startups In the Southeast Asia',
#   {'entities': [(5, 12, 'Startups_flt')]}),
#  ('Compufirst raised an undisclosed amount / Series Unknown from Entrepreneur Venture',
#   {'entities': [(62, 74, 'Startups_flt')]}),
#  ('Glacier Bancorp, Inc. Increases Quarterly Dividend',
#   {'entities': [(42, 50, 'revenuegrowth_flt')]}),
#  ('Entrepreneur Lance Stokes, formerly of Lauren James fame, making comeback with new tech venture',
#   {'entities': [(0, 12, 'Startups_flt')]}),
#  ('NaviMed Capital Announces Expansion of Investment and Operations Teams',
#   {'entities': [(39, 49, 'revenuegrowth_flt')]}),
#  ('1315 Capital Announces the Addition of Senior Investment Professional',
#   {'entities': [(46, 56, 'revenuegrowth_flt')]}),
#  ('Deals To Robotics Startups See An Uptick As One Company Joins The Unicorn Club',
#   {'entities': [(18, 26, 'Startups_flt')]}),
#  ('Robots R’ Us: Funding And Deal Activity To Robotics See New Highs In 2015',
#   {'entities': [(14, 21, 'Funding_flt')]}),
#  ('How This Startup Is Disrupting The Equipment Financing Market',
#   {'entities': [(9, 16, 'Startups_flt')]}),
#  ('Currency Alliance raised an undisclosed amount / Non Equity Assistance from Hackquarters',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('Currency Alliance raised €320,000 / Seed',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('Currency Alliance raised €500,000 / Seed from HOWZAT Partners',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('Currency Alliance raised €315,000 / Seed from HOWZAT Partners',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('Currency Alliance raised €400,000 / Seed from HOWZAT Partners and VenturCap',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('Currency Alliance raised €200,000 / Seed',
#   {'entities': [(9, 17, 'Alliance_flt')]}),
#  ('EcoTarium staff in Worcester call for resignation of CEO Lucy Hale as museum announces extended closure, expected layoffs',
#   {'entities': [(38, 49, 'ManagementMove_flt')]}),
#  ('Startup of the Week - MusicGurus', {'entities': [(0, 7, 'Startups_flt')]}),
#  ('MusicGurus raised £164,513 / Equity Crowdfunding from Crowdcube',
#   {'entities': [(36, 48, 'Startups_flt')]}),
#  ('MusicGurus raised £172,590 / Equity Crowdfunding',
#   {'entities': [(36, 48, 'Startups_flt')]}),
#  ('Eloquens raised an undisclosed amount / Pre Seed from adVentures Startup Studio',
#   {'entities': [(65, 72, 'Startups_flt')]}),
#  ('Aidrivers successfully completes its latest funding round to scale up production to meet market demand',
#   {'entities': [(44, 51, 'Funding_flt')]}),
#  ('Kriya acquires gene therapy startup for undisclosed sum; Compugen wins milestone payment from AstraZeneca',
#   {'entities': [(28, 35, 'Startups_flt')]}),
#  ('YourStory recently caught up with Entrepreneur Sharadha Ramakrishnan, founder Monkey Creative Labs, on what it takes to translate an idea to enterprise.',
#   {'entities': [(34, 46, 'Startups_flt')]}),
#  ('MINA Token Trading on OKEx, Kraken, Coinlist at Around $3',
#   {'entities': [(11, 18, 'IPO_flt')]}),
#  ('EV charging payment startup Mina now valued at £6M after raising latest funding',
#   {'entities': [(20, 27, 'Startups_flt')]}),
#  ('Music Hotpot raised an undisclosed amount / Non Equity Assistance from Taiwan Startup Stadium',
#   {'entities': [(78, 85, 'Startups_flt')]}),
#  ('Fintech Firm Currencycloud Partners with Scottish Startup Skedadle',
#   {'entities': [(50, 57, 'Startups_flt')]}),
#  ('Currencycloud, Mastercard join new Fintech Foundation incubator',
#   {'entities': [(54, 63, 'Startups_flt')]}),
#  ('GeoWealth Secures $19 Million in Series B Funding Led by Kayne Anderson Capital Advisors with Follow-on Investment from J.P. Morgan Asset Management',
#   {'entities': [(42, 49, 'Funding_flt')]}),
#  ('Navina raised an undisclosed amount / Grant from Israel Innovation Authority',
#   {'entities': [(56, 66, 'revenuegrowth_flt')]}),
#  ('Navina Secures $15M in Series A Funding',
#   {'entities': [(32, 39, 'Funding_flt')]}),
#  ('MedTech startup Navina raises $7M, taming medical data chaos with the power of AI',
#   {'entities': [(8, 15, 'Startups_flt')]}),
#  ('Currency.com US crypto exchange launches with trading of bitcoin',
#   {'entities': [(46, 53, 'IPO_flt')]}),
#  ('Imagen Therapeutics raised £112,626 / Equity Crowdfunding from Crowdcube',
#   {'entities': [(45, 57, 'Startups_flt')]}),
#  ('Imagen Therapeutics raised £4,250,000 / funding round',
#   {'entities': [(40, 47, 'Funding_flt')]}),
#  ('Imagen Therapeutics raised £1,000,000 / Equity Crowdfunding',
#   {'entities': [(47, 59, 'Startups_flt')]}),
#  ('Navin raised an undisclosed amount / Seed from Microsoft Accelerator',
#   {'entities': [(57, 68, 'Startups_flt')]}),
#  ('DigitalOcean Stock Closes Below IPO Price On First Day Of Trading',
#   {'entities': [(32, 35, 'Funding_flt')]}),
#  ('Seasoned executives for startups',
#   {'entities': [(24, 32, 'Startups_flt')]}),
#  ('Prism Group AG acquisition of Finablr and Amir Nagammy’s vision for the company’s future',
#   {'entities': [(15, 26, 'ManagementMove_flt')]}),
#  ('Eloquii Announces Winner Of BIPOC Plus-Size Fashion Award',
#   {'entities': [(52, 57, 'Award_flt')]}),
#  ('Eloquii, The Curvy Fashionista Disclose Winners of The Cultivate Award',
#   {'entities': [(65, 70, 'Award_flt')]}),
#  ('Panzura raised $80,000,000 / Series B from CIBC Innovation Banking and Kayne Partners',
#   {'entities': [(48, 58, 'revenuegrowth_flt')]}),
#  ("Why Digirad's Stock Is Trading Higher Today",
#   {'entities': [(23, 30, 'IPO_flt')]}),
#  ('Why Sun Communities Is Trading Lower Today',
#   {'entities': [(23, 30, 'IPO_flt')]}),
#  ("Kaynes Technology's IPO subscribed 23 pc on day 1, retail portion subscribed 12%",
#   {'entities': [(20, 23, 'Funding_flt')]}),
#  ('Startup facilitating data flow between payers providers raises $5.5M',
#   {'entities': [(0, 7, 'Startups_flt')]}),
#  ('Pickpocket raised $286,000 / funding round',
#   {'entities': [(29, 36, 'Funding_flt')]}),
#  ('PSG Group says restructuring plans on track',
#   {'entities': [(15, 28, 'Layoffs_flt')]}),
#  ('Kaynes raises Rs 257 crore from anchor investors ahead of IPO',
#   {'entities': [(58, 61, 'Funding_flt')]}),
#  ('Kaynes Tech IPO opens for subscription tomorrow. Details inside',
#   {'entities': [(12, 15, 'Funding_flt')]}),
#  ('Streamline Innovations raised an undisclosed amount / Series Unknown from Energy Innovation Capital and Pearl Energy Investments',
#   {'entities': [(11, 21, 'revenuegrowth_flt')]}),
#  ('INVESTOR ALERT: Monteverde & Associates PC Launches Legal Inquiry Regarding the Following Mergers',
#   {'entities': [(0, 8, 'Funding_flt')]}),
#  ('Padlock Partners UK Fund II Completes Acquisition of Huntingdon Self-Storage Property',
#   {'entities': [(38, 49, 'ManagementMove_flt')]}),
#  ('Padlock Partners UK Fund I announces acquisition of land and development agreement in Newmarket, England',
#   {'entities': [(37, 48, 'ManagementMove_flt')]}),
#  ('Padlock Partners UK Fund I Completes Acquisition of Initial Properties',
#   {'entities': [(37, 48, 'ManagementMove_flt')]}),
#  ('CurrencyFair exchange firm bullish, as fintech merger promises growth despite €4.2m loss in 2020',
#   {'entities': [(47, 53, 'ManagementMove_flt')]}),
#  ('Veteran fintech Assembly Payments rebrands as Zai following CurrencyFair merger',
#   {'entities': [(73, 79, 'ManagementMove_flt')]}),
#  ('Currencyfair got $35m investment during merger with Australian firm',
#   {'entities': [(22, 32, 'revenuegrowth_flt')]}),
#  ('CurrencyFair merger to create hundreds of jobs in next few years',
#   {'entities': [(13, 19, 'ManagementMove_flt')]}),
#  ('CurrencyFair and Assembly Payments to Merge After Investment from Standard Chartered',
#   {'entities': [(50, 60, 'revenuegrowth_flt')]}),
#  ('SEC insider trading charge: Enter the SanDisk man',
#   {'entities': [(12, 19, 'IPO_flt')]}),
#  ('Fintech startup SelfScore reels in $7 mln',
#   {'entities': [(8, 15, 'Startups_flt')]}),
#  ('Kleiner Device Labs to Present at McKinsey & Company Early Stage Investor Conference',
#   {'entities': [(65, 73, 'Funding_flt')]}),
#  ('Kleiner Device Labs to Present at McKinsey & Company Early Stage Investor Conference',
#   {'entities': [(65, 73, 'Funding_flt')]}),
#  ("Spine surgeon's startup wants a slice of the $14B spinal fusion market",
#   {'entities': [(16, 23, 'Startups_flt')]}),
#  ('This Medical Startup Could Disrupt The $14 Billion Spinal Fusion Market: Last Call To Invest',
#   {'entities': [(13, 20, 'Startups_flt')]}),
#  ('CompuGroup Medical confirms market-leading position with strategic acquisition of Medicus Laboratory Information Systems',
#   {'entities': [(67, 78, 'ManagementMove_flt')]}),
#  ('CompuGroup Medical raised €200,000,000 / Debt Financing from European Investment Bank',
#   {'entities': [(70, 80, 'revenuegrowth_flt')]}),
#  ('CXI completes acquisition of Canadian payments business',
#   {'entities': [(14, 25, 'ManagementMove_flt')]}),
#  ('An investment idea born on the beach',
#   {'entities': [(3, 13, 'revenuegrowth_flt')]}),
#  ('PrismHR announces The Work Number from Equifax to Provide Automated Employment and Income Verifications to Its HRO Partners, Their Small Business Customers and Employees',
#   {'entities': [(68, 78, 'Openpositions_flt')]}),
#  ('Green Life Buildings raised an undisclosed amount / Secondary Market from Crimson Investment Fund',
#   {'entities': [(82, 92, 'revenuegrowth_flt')]}),
#  ('Green Life Buildings raised £600,000 / Seed from Midlands Engine Investment Fund',
#   {'entities': [(65, 75, 'revenuegrowth_flt')]}),
#  ('Pearler secures $7.8 million in seed funding led by Portage Ventures',
#   {'entities': [(37, 44, 'Funding_flt')]}),
#  ('InterPrice Technologies Raises $7.3M in Series A Funding',
#   {'entities': [(49, 56, 'Funding_flt')]}),
#  ('Nexio and Complete Merchant Solutions Announce Brand Consolidation',
#   {'entities': [(53, 66, 'M&A_flt')]}),
#  ('Pearlfection raised an undisclosed amount / Series Unknown from Logan Capital AG and Mountain Alliance',
#   {'entities': [(94, 102, 'Alliance_flt')]}),
#  ('Lateral Investment Management raised an undisclosed amount / Series Unknown from Kayon Partners',
#   {'entities': [(8, 18, 'revenuegrowth_flt')]}),
#  ('Pickr secures £1m to disrupt recruitment market',
#   {'entities': [(29, 40, 'HiringPlan_flt')]}),
#  ('Kleinfelder Completes Acquisition of Century Engineering, Inc., a Full-Service, Multidisciplinary Engineering Firm Based in Mid-Atlantic Region',
#   {'entities': [(22, 33, 'ManagementMove_flt')]}),
#  ('Eco-Tech Ceram raised €400,000 / Equity Crowdfunding from Lita.co',
#   {'entities': [(40, 52, 'Startups_flt')]}),
#  ('Tedros Has Failed Us on COVID-19: AHF Calls for His Resignation within 72 Hours',
#   {'entities': [(52, 63, 'ManagementMove_flt')]}),
#  ('AbleDocs Inc. and Sitemorse Reach an Acquisition Agreement',
#   {'entities': [(37, 48, 'ManagementMove_flt')]}),
#  ('AbleDocs Inc. Announces the Acquisition of Web Key IT',
#   {'entities': [(28, 39, 'ManagementMove_flt')]}),
#  ('DaVita Inc. Schedules 4th Quarter 2022 Investor Conference Call',
#   {'entities': [(39, 47, 'Funding_flt')]}),
#  ('Guild Capital, Omidyar lead funding in logistics-tech startup Pickrr',
#   {'entities': [(28, 35, 'Funding_flt')]}),
#  ('Exclusive: Pickrr raises seed funding from Palaash Ventures, others',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('McorpCX, Inc. Announces Plan for Strategic Divestiture of its Professional Services Business',
#   {'entities': [(43, 54, 'ManagementMove_flt')]}),
#  ('Kaypok raised an undisclosed amount / Pre Seed from Toronto Innovation Acceleration Partners',
#   {'entities': [(60, 70, 'revenuegrowth_flt')]}),
#  ('Pearl Global Industries announces acquisition of Alpha Clothing Ltd',
#   {'entities': [(34, 45, 'ManagementMove_flt')]}),
#  ('Quintiles and DaVita Clinical Research Announce Strategic Alliance',
#   {'entities': [(58, 66, 'Alliance_flt')]}),
#  ('Quintiles and DaVita Clinical Research Announce Strategic Alliance',
#   {'entities': [(58, 66, 'Alliance_flt')]}),
#  ('Virtual cardiology startup Heartbeat lands $20M',
#   {'entities': [(19, 26, 'Startups_flt')]}),
#  ('Wellth Raises $10M in Funding', {'entities': [(22, 29, 'Funding_flt')]}),
#  ("FTC gives the OK for UnitedHealth's acquisition of DaVita Medical Group",
#   {'entities': [(36, 47, 'ManagementMove_flt')]}),
#  ("Singapore's NOVI Health secures $5m fresh funding from Monk's Hill",
#   {'entities': [(42, 49, 'Funding_flt')]}),
#  ('Entrepreneur Monk Mode', {'entities': [(0, 12, 'Startups_flt')]}),
#  ('Property data startup Urbanmetry scores US$2M pre-Series A led by Monk’s Hill',
#   {'entities': [(14, 21, 'Startups_flt')]}),
#  ('Microvast raised $540,000,000 / Post Ipo Equity from BlackRock and 3 other investors',
#   {'entities': [(37, 40, 'Funding_flt')]}),
#  ('Aeva goes public via merger with InterPrivate',
#   {'entities': [(21, 27, 'ManagementMove_flt')]}),
#  ('Aeva and InterPrivate Acquisition Corp. Announce Closing of Business Combination; Aeva to Trade on NYSE as "AEVA" Beginning On March 15',
#   {'entities': [(22, 33, 'ManagementMove_flt')]}),
#  ('Data Center Exec-Led Digital Infrastructure SPAC Raises $250M in IPO',
#   {'entities': [(65, 68, 'Funding_flt')]}),
#  ('Sylebra supports Aeva and InterPrivate merger',
#   {'entities': [(39, 45, 'ManagementMove_flt')]}),
#  ('Sensor startup led by ex-Apple engineers raises $200 million more ahead of public debut',
#   {'entities': [(7, 14, 'Startups_flt')]}),
#  ('After giving up on Nasdaq, Compulab files for TASE IPO',
#   {'entities': [(51, 54, 'Funding_flt')]}),
#  ('There’s another small tech IPO and we’re really just waiting for Blue Apron',
#   {'entities': [(27, 30, 'Funding_flt')]}),
#  ('Acquisition adds to Nexira’s hydrocolloids portfolio',
#   {'entities': [(0, 11, 'ManagementMove_flt')]}),
#  ('Startup Spotlight: Horizon uses existing communities to create local hospitality networks - GeekWire',
#   {'entities': [(0, 7, 'Startups_flt')]}),
#  ('Arbisoft Has Made a Strategic Investment in Cheetay',
#   {'entities': [(30, 40, 'revenuegrowth_flt')]}),
#  ('Navios Maritime Partners L.P. (NYSE:NMM) Declares $0.05 Quarterly Dividend',
#   {'entities': [(66, 74, 'revenuegrowth_flt')]}),
#  ('Navios Maritime Partners reports Q1 adjusted EPS $1.01, two est. $1.73',
#   {'entities': [(45, 48, 'Earningsreport_flt')]}),
#  ('Navios Maritime Partners completes acquisition of Navios Maritime Containers',
#   {'entities': [(35, 46, 'ManagementMove_flt')]}),
#  ('Navios Maritime Partners reports Q4 adjusted EPS $1.12, two est. $1.00',
#   {'entities': [(45, 48, 'Earningsreport_flt')]}),
#  ('Navios Maritime Partners, Navios Maritime Containers announce merger approval',
#   {'entities': [(62, 68, 'ManagementMove_flt')]}),
#  ('The Accidental Crypto Investor', {'entities': [(22, 30, 'Funding_flt')]}),
#  ('This Investor Is Architecting the Cryptoverse',
#   {'entities': [(5, 13, 'Funding_flt')]}),
#  ('ABLE Equipment Rental Wins 2019 Rising Star Award at Access, Lift & Handlers Conference and Awards',
#   {'entities': [(44, 49, 'Award_flt')]}),
#  ('30 startups portuguesas rumam ao Canadá, incluindo a INLIFE',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('INLIFE e outras 29 startups portuguesas à conquista do Canadá',
#   {'entities': [(19, 27, 'Startups_flt')]}),
#  ('Prism Medical raised $7,000,000 / Post Ipo Equity from Yellow Point Equity Partners',
#   {'entities': [(39, 42, 'Funding_flt')]}),
#  ('Navipoint Genomics raised $175,000 / Grant from The University of Chicago Innovation Fund',
#   {'entities': [(74, 84, 'revenuegrowth_flt')]}),
#  ('Prism Medical & Design raised an undisclosed amount / Equity Crowdfunding',
#   {'entities': [(61, 73, 'Startups_flt')]}),
#  ('I-Corps@Ohio teams support innovation and create economic development',
#   {'entities': [(27, 37, 'revenuegrowth_flt')]}),
#  ('Green Light raised $200,000 / funding round',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('BNP Paribas joins €40 million funding round in climate data outfit Kayrros',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('French climate tech startup Kayrros raises €40 million to help companies and policymakers achieve sustainability goals',
#   {'entities': [(20, 27, 'Startups_flt')]}),
#  ('Planet Signs Deal With European Energy Analytics Startup Kayrros',
#   {'entities': [(49, 56, 'Startups_flt')]}),
#  ('Kayrros raised $24,400,000 / Series B from Cathay Innovation and 4 other investors',
#   {'entities': [(50, 60, 'revenuegrowth_flt')]}),
#  ('EmployStream Raises $7M in Series B Funding',
#   {'entities': [(36, 43, 'Funding_flt')]}),
#  ('EmployStream Launches New Products to Improve Credentialing and Compliance Experience for Healthcare Staffing Firms',
#   {'entities': [(101, 109, 'Openpositions_flt')]}),
#  ('Thundersoft’s acquisition of Rightware',
#   {'entities': [(14, 25, 'ManagementMove_flt')]}),
#  ("The DeanBeat: It's time for the U.S. to wake up and support game startups | GamesBeat | Games | by Dean Takahashi",
#   {'entities': [(65, 73, 'Startups_flt')]}),
#  ('Nexite Closes $100M Funding for its Breakthrough, Connected Merchandise Platform Delivering eCommerce Level Intelligence for Physical Retail Stores',
#   {'entities': [(20, 27, 'Funding_flt')]}),
#  ('Nexite Raises $67M in Series C Funding',
#   {'entities': [(31, 38, 'Funding_flt')]}),
#  ('Arcane Crypto raised $6,000,000 / Post Ipo Equity from Klein Invest AS and Lucerne Capital Management',
#   {'entities': [(39, 42, 'Funding_flt')]}),
#  ('1,5 Millionen Euro für Innsbrucker Start-up Monkee',
#   {'entities': [(35, 43, 'Startups_flt')]}),
#  ('Monkee raised an undisclosed amount / Grant from The Austrian Research Promotion Agency (FFG)',
#   {'entities': [(71, 80, 'Promotion_flt')]}),
#  ('RQSTIVAL raised NOK1,000,000 / Seed from Klein Investment Group',
#   {'entities': [(47, 57, 'revenuegrowth_flt')]}),
#  ('RQSTIVAL raised NOK1,000,000 / Angel from Klein Investment Group',
#   {'entities': [(48, 58, 'revenuegrowth_flt')]}),
#  ('UniversityAngels.com raised $2,000,000 / Series Unknown from Klein Investment Group',
#   {'entities': [(67, 77, 'revenuegrowth_flt')]}),
#  ("A 'down year' for Pennsylvania football leads Penn State on a longer recruiting trail",
#   {'entities': [(69, 79, 'Openpositions_flt')]}),
#  ('The Israeli startups taking NYC property-tech by storm',
#   {'entities': [(12, 20, 'Startups_flt')]}),
#  ('Nexity Network joined Startup with Chainlink',
#   {'entities': [(22, 29, 'Startups_flt')]}),
#  ('Nexity Joins Polygon Accelerator Program',
#   {'entities': [(21, 32, 'Startups_flt')]}),
#  ('Nexity Joins Polygon DAO Accelerator Program After Receiving Development Grant',
#   {'entities': [(25, 36, 'Startups_flt')]}),
#  ('ImageQ raised CN¥27,000,000 / Series A from Hubei Gaotou Jinyun Jiguang Industry Investment Management and Hubei Provincial High Technology Industry Investment',
#   {'entities': [(81, 91, 'revenuegrowth_flt')]}),
#  ('ImageQ raised CN¥3,000,000 / Angel from Wuhan Youjiale Financial Investment Center',
#   {'entities': [(65, 75, 'revenuegrowth_flt')]}),
#  ('ImageQ raised CN¥1,000,000 / Seed from Guangzhou Zhongcheng Jiqi Materials Trading',
#   {'entities': [(75, 82, 'IPO_flt')]}),
#  ('Healthcare Needs More Diverse Experts To Guide Innovation',
#   {'entities': [(47, 57, 'revenuegrowth_flt')]}),
#  ('Inlightened Launches to Drive Responsible Disruption in Healthcare Innovation',
#   {'entities': [(67, 77, 'revenuegrowth_flt')]}),
#  ('RED STAR raised CN¥20,000,000 / Series B from DSH Capital and Tengary Investment',
#   {'entities': [(70, 80, 'revenuegrowth_flt')]}),
#  ('ECOTEC Solutions raised an undisclosed amount / funding round from Intrepid Investment Management',
#   {'entities': [(48, 55, 'Funding_flt')]}),
#  ("State Street's Currenex to provide trading architecture for Pure Digital platform",
#   {'entities': [(35, 42, 'IPO_flt')]}),
#  ('Will the U.S. second oldest bank State Street start trading crypto?',
#   {'entities': [(52, 59, 'IPO_flt')]}),
#  ('OANDA launches institutional trading platform',
#   {'entities': [(29, 36, 'IPO_flt')]}),
#  ('LaunchAngels Hopes to Consolidate Crowdfunding for Startup Investors',
#   {'entities': [(34, 46, 'Startups_flt')]}),
#  ('Currensee: Currensee Launches New Trade Leaders Investment Program',
#   {'entities': [(48, 58, 'revenuegrowth_flt')]}),
#  ('Odd couple: two-year-old New York startup merges with 86-year-old Idaho brokerage',
#   {'entities': [(34, 41, 'Startups_flt')]}),
#  ('eToro Launches Social Trading Index', {'entities': [(22, 29, 'IPO_flt')]}),
#  ('The good, the bad, and the ugly of web startups at DEMO Asia | VentureBeat | News | by VentureBeat',
#   {'entities': [(39, 47, 'Startups_flt')]}),
#  ('30 Startup Terpilih Untuk MaGIC Global Accelerator Programme 2019',
#   {'entities': [(3, 10, 'Startups_flt')]}),
#  ('Cargotec Corporation : Cargotec sells Navis business to technology investment firm Accel-KKR for an enterprise value of EUR 380 million',
#   {'entities': [(67, 77, 'revenuegrowth_flt')]}),
#  ('Davis H. Elliot Co. announces promotion of Scott Navis to CFO',
#   {'entities': [(30, 39, 'Promotion_flt')]}),
#  ('Global Container Terminals (GCT) Continues to Invest in Innovation with Navis N4',
#   {'entities': [(56, 66, 'revenuegrowth_flt')]}),
#  ('Startup Leaders, Here’s How To Build A Successful Advisory Board',
#   {'entities': [(0, 7, 'Startups_flt')]}),
#  ('IT Hiring After California’s AB5 Legislation',
#   {'entities': [(3, 9, 'ManagementMove_flt')]}),
#  ('GreenLight.ai raised an undisclosed amount / funding round from TSVC',
#   {'entities': [(45, 52, 'Funding_flt')]}),
#  ('Agriculture Tech Market Map: 77 Startups Powering The Future Of Farming And Agribusiness',
#   {'entities': [(32, 40, 'Startups_flt')]}),
#  ('Here Are The 52 Startups That Launched At Y Combinator Summer 2015 Demo Day\xa02',
#   {'entities': [(16, 24, 'Startups_flt')]}),
#  ('Entrepreneur Viraj Sheth on his entrepreneurial journey and starting influencer marketing agency Monk Entertainment',
#   {'entities': [(0, 12, 'Startups_flt')]}),
#  ('Learning platform 90+ My Tuition Raises $5 Mn From Pearl Investment LLC',
#   {'entities': [(57, 67, 'revenuegrowth_flt')]}),
#  ('90+ My Tuition App raised $5,000,000 / Series A from Pearl Investment',
#   {'entities': [(59, 69, 'revenuegrowth_flt')]}),
#  ('Fortanix Raises $90 Million in Series C Funding Led by Goldman Sachs Asset Management',
#   {'entities': [(40, 47, 'Funding_flt')]}),
#  ('We got an exclusive look at the 14-slide pitch deck data encryption startup Fortanix used to raise $90 million from investors like Goldman Sachs',
#   {'entities': [(68, 75, 'Startups_flt')]}),
#  ('Fusion Medical Staffing Celebrates Christmas with Angeles Among Us, Helping Families with Pediatric Cancer',
#   {'entities': [(15, 23, 'Openpositions_flt')]}),
#  ('Fusion Medical Staffing Takes Corporate Responsibility to the Next Level',
#   {'entities': [(15, 23, 'Openpositions_flt')]}),
#  ('Fusion Medical Staffing Earns Top Honors “2018 Best Workplaces – Inc.com"',
#   {'entities': [(15, 23, 'Openpositions_flt')]}),
#  ('Fusion Medical Staffing Wins Highly Coveted Award "2018 Best Staffing Firm to Work For in North America"',
#   {'entities': [(15, 23, 'Openpositions_flt')]}),
#  ('Andreessen Horowitz–backed neobank Current explains why launching crypto trading during a massive downturn is actually good timing',
#   {'entities': [(73, 80, 'IPO_flt')]}),
#  ('Aidyia raised $20,000,000 / funding round',
#   {'entities': [(28, 35, 'Funding_flt')]}),
#  ('Pearl Jiu raised CN¥20,000,000 / Series A from Shenzhen Tianying Chuangfu Investment Consulting',
#   {'entities': [(74, 84, 'revenuegrowth_flt')]}),
#  ('PICKUP Raises $15M Series B Funding to Meet Demand for Omnichannel Delivery as a Service',
#   {'entities': [(28, 35, 'Funding_flt')]}),
#  ('Top 25 MedTech Startups', {'entities': [(15, 23, 'Startups_flt')]}),
#  ('Regenerative robots: six medtech startups helping people heal',
#   {'entities': [(33, 41, 'Startups_flt')]}),
#  ('Singapore Aquaculture Innovation Studio Kicks Off',
#   {'entities': [(22, 32, 'revenuegrowth_flt')]}),
#  ('ADMA Biologics raised $60,000,000 / Post Ipo Equity',
#   {'entities': [(41, 44, 'Funding_flt')]}),
#  ('ADMA Biologics raised $150,000,000 / Post Ipo Debt from Hayfin Capital Management',
#   {'entities': [(42, 45, 'Funding_flt')]}),
#  ('GreenLight Biosciences to Participate in Upcoming Investor Conferences in November',
#   {'entities': [(50, 58, 'Funding_flt')]}),
#  ('Greenlight Biosciences raised $109,000,000 / Post Ipo Equity from BNP Paribas Asset Management and 11 other investors',
#   {'entities': [(50, 53, 'Funding_flt')]}),
#  ('ADMA Biologics Receives BioNJ 2020 Innovator Award for ASCENIV™',
#   {'entities': [(35, 44, 'Startups_flt')]}),
#  ('Prism Pharmaceuticals raised $15,000,000 / Series C from Innovation Network Corporation of Japan',
#   {'entities': [(57, 67, 'revenuegrowth_flt')]}),
#  ('Image Resources NL (ASX:IMA) Annual Dividend',
#   {'entities': [(36, 44, 'revenuegrowth_flt')]}),
#  ('Image Resources NL (ASX:IMA) Investor Presentation - TZMI Virtual Congress',
#   {'entities': [(29, 37, 'Funding_flt')]}),
#  ('Fusion Microfinance shares list at discount to IPO issue price',
#   {'entities': [(47, 50, 'Funding_flt')]}),
#  ('Fusion Micro Fin makes dull debut, Inox Green IPO subscribed 1.55x & more',
#   {'entities': [(46, 49, 'Funding_flt')]}),
#  ('Fusion Micro Finance IPO Allotment today: Here’s how to check your status online',
#   {'entities': [(21, 24, 'Funding_flt')]}),
#  ('Fusion Microfinance IPO allotment date today. GMP, how to check allotment status',
#   {'entities': [(20, 23, 'Funding_flt')]}),
#  ('InterQuest Group acquired ECOM Recruitment for an undisclosed amount',
#   {'entities': [(31, 42, 'HiringPlan_flt')]}),
#  ('InterQuest Group acquired Korus Recruitment Group for an undisclosed amount',
#   {'entities': [(32, 43, 'HiringPlan_flt')]}),
#  ('InterQuest Group acquired Intelect Recruitment for $3,725,000',
#   {'entities': [(35, 46, 'HiringPlan_flt')]}),
#  ('Beta Hatch Closes Series A1 Funding Round',
#   {'entities': [(28, 35, 'Funding_flt')]}),
#  ('Klein Private Equity Investment',
#   {'entities': [(21, 31, 'revenuegrowth_flt')]}),
#  ('Able Innovations, Cognota, BlueDot among recipients of $14 million FedDev investment',
#   {'entities': [(74, 84, 'revenuegrowth_flt')]}),
#  ('MATTER Startup Spotlight: Able Innovations',
#   {'entities': [(7, 14, 'Startups_flt')]}),
#  ('Able Innovations works to transform frontline healthcare with USD $6MM in funding',
#   {'entities': [(74, 81, 'Funding_flt')]}),
#  ('Able Innovations Inc. Winner: VHA Innovation Experience kicks off with 10 Breaking Boundaries: Collaboration Challenge winners named',
#   {'entities': [(5, 15, 'revenuegrowth_flt')]}),
#  ('Twitter raised an undisclosed amount / Post Ipo Equity from Greenlight Capital',
#   {'entities': [(44, 47, 'Funding_flt')]}),
#  ('Prismpop Raised $5M in Total Seed Funding',
#   {'entities': [(34, 41, 'Funding_flt')]}),
#  ('New social shopping platform Prismpop has raised $5M total seed funding to help consumers discover what to buy',
#   {'entities': [(64, 71, 'Funding_flt')]}),
#  ('6 startups using games to change how kids learn',
#   {'entities': [(2, 10, 'Startups_flt')]}),
#  ('Top 13 Music and Edtech Startups You Need to Know About in 2017',
#   {'entities': [(24, 32, 'Startups_flt')]}),
#  ('Ranking 100 Open Startups destaca as TOP 10 HealthTechs mais atraentes para o mercado em 2020',
#   {'entities': [(17, 25, 'Startups_flt')]}),
#  ('Online mental health startup PsyAlive registers 600% growth of consultations',
#   {'entities': [(21, 28, 'Startups_flt')]}),
#  ('Pearlmark Closes $14.5 Million Mezzanine Loan Investment for Office Complex in Schaumburg, IL',
#   {'entities': [(46, 56, 'revenuegrowth_flt')]}),
#  ('Nexla Raises $12M in Series A Funding',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('Able Jobs raised an undisclosed amount / Non Equity Assistance from Google for Startups',
#   {'entities': [(79, 87, 'Startups_flt')]}),
#  ('SAIF Partners, Y Combinator sign seed cheques for hiring platform Able Jobs',
#   {'entities': [(50, 56, 'ManagementMove_flt')]}),
#  ('Meet Music Lover’s founder Bav Kong the new face in the Cambodia startup fraternity',
# ...
#  ('Indonesia’s climate tech venture builder Ecoxyztem secures investment',
#   {'entities': [(59, 69, 'revenuegrowth_flt')]}),
#  ('Pendanaan Ecoxyztem untuk Mengembangkan Climate-Tech Startup',
#   {'entities': [(53, 60, 'Startups_flt')]}),
#  ('monoAI technology raised ¥750,000,000 / Series Unknown from Sony Innovation Fund',
#   {'entities': [(65, 75, 'revenuegrowth_flt')]}),
#  ('La start-up Imagilys scrute les neurones à la loupe',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('Cleveland medical technology startup wins Ohio Third Frontier funding',
#   {'entities': [(29, 36, 'Startups_flt')]}),
#  ('Battle Sight Technologies raised $100,000 / Grant from Ohio Third Frontier and Startup Fund',
#   {'entities': [(79, 86, 'Startups_flt')]}),
#  ('Ohio Third Frontier awards commercialization, startup fund at NE Ohio universities',
#   {'entities': [(46, 53, 'Startups_flt')]}),
#  ('Third Frontier awards more than $9 million in funding for Northeast Ohio',
#   {'entities': [(46, 53, 'Funding_flt')]}),
#  ('NAVVI raised $5,000 / Equity Crowdfunding',
#   {'entities': [(29, 41, 'Startups_flt')]}),
#  ('GreenMark Biomedical Secures Follow-on Investment',
#   {'entities': [(39, 49, 'revenuegrowth_flt')]}),
#  ('GreenMark Biomedical Secures $670k in Additional Funding',
#   {'entities': [(49, 56, 'Funding_flt')]}),
#  ('Deep tech startup Ecozen raises $25M led by Nuveen, Dare Ventures',
#   {'entities': [(10, 17, 'Startups_flt')]}),
#  ('Agritech startup Ecozen raises $10M from Nuveen Global Fund',
#   {'entities': [(9, 16, 'Startups_flt')]}),
#  ('Deep-tech startup Ecozen focuses on climate-smart solutions for farming',
#   {'entities': [(10, 17, 'Startups_flt')]}),
#  ('PrivacyCloud raised €300,000 / Seed from The Regional Promotion Society of the Principality of Asturias',
#   {'entities': [(54, 63, 'Promotion_flt')]}),
#  ('Ecozenith raised an undisclosed amount / Equity Crowdfunding',
#   {'entities': [(48, 60, 'Startups_flt')]}),
#  ('Tiger Global’s Startup Business Holds Up Against Bear Market',
#   {'entities': [(15, 22, 'Startups_flt')]}),
#  ("AiHuiShou Discusses Corporate Social Responsibilities at 36Kr's Investor Summit",
#   {'entities': [(64, 72, 'Funding_flt')]}),
#  ('JD.com merges its secondhand trading platform Paipai with startup Aihuishou',
#   {'entities': [(29, 36, 'IPO_flt')]}),
#  ('Laundrygo raised ₩49,500,000,000 / Series C from Aju IB Investment and 8 other investors',
#   {'entities': [(56, 66, 'revenuegrowth_flt')]}),
#  ('Musinsa’s SoldOut gets $89 million investment as limited-edition sneakers resale heats up',
#   {'entities': [(35, 45, 'revenuegrowth_flt')]}),
#  ('MUSINSA raised ₩130,000,000,000 / Series Unknown from IMM Investment and Sequoia Capital',
#   {'entities': [(58, 68, 'revenuegrowth_flt')]}),
#  ('KT pushes ahead with K Bank IPO', {'entities': [(28, 31, 'Funding_flt')]}),
#  ('Top-12 Artificial Intelligence Startups in Sweden',
#   {'entities': [(31, 39, 'Startups_flt')]}),
#  ('Imagimob: Press Release: AI-startup Imagimob adds new investor and accelerates expansion',
#   {'entities': [(54, 62, 'Funding_flt')]}),
#  ('Aihui Health raised an undisclosed amount / Series B from Haichuang Medical Investment',
#   {'entities': [(76, 86, 'revenuegrowth_flt')]}),
#  ('Korean startup AKA develops its AI-Driven ‘MUSE’ and Robot MUSIO to connect humans & technology',
#   {'entities': [(7, 14, 'Startups_flt')]}),
#  ('INM Holdings Japan raised ¥20,000,000 / Series Unknown from Energy & Environment Investment and Nissay Capital',
#   {'entities': [(81, 91, 'revenuegrowth_flt')]}),
#  ('INM Holdings Japan raised ¥200,000,000 / Series Unknown from Energy & Environment Investment and Nissay Capital',
#   {'entities': [(82, 92, 'revenuegrowth_flt')]}),
#  ('NavVis adds fresh funding to fulfill its mission to digitize commercial buildings and assets',
#   {'entities': [(18, 25, 'Funding_flt')]}),
#  ('NavVis raised €20,000,000 / Debt Financing from European Investment Bank',
#   {'entities': [(57, 67, 'revenuegrowth_flt')]}),
#  ('European Investment Bank provides Munich-based NavVis with €20 million to cement their market leading position in digital twin technology',
#   {'entities': [(9, 19, 'revenuegrowth_flt')]}),
#  ('Seattle gaming startup Polyarc grows team as it brings ‘Moss: Book 2’ to Oculus',
#   {'entities': [(15, 22, 'Startups_flt')]}),
#  ('Moss dev Polyarc secures $9m investment to branch into augmented reality',
#   {'entities': [(29, 39, 'revenuegrowth_flt')]}),
#  ('Ukranian Bank Monobank To Start Offering Bitcoin Trading',
#   {'entities': [(49, 56, 'IPO_flt')]}),
#  ('Behavioral Biometrics Leader BioCatch Closes $30M New Investment',
#   {'entities': [(54, 64, 'revenuegrowth_flt')]}),
#  ('SCADAfence raised $10,000,000 / Series A from 31Ventures Global Innovation Fund and 7 other investors',
#   {'entities': [(64, 74, 'revenuegrowth_flt')]}),
#  ('Navvisa raised an undisclosed amount / Seed from Alchemist Accelerator',
#   {'entities': [(59, 70, 'Startups_flt')]}),
#  ('Detroit’s Navv Systems Announces Close of $3.2M Funding Round Led by Arboretum Ventures',
#   {'entities': [(48, 55, 'Funding_flt')]}),
#  ('Patrick Soon-Shiong Innovation Awards 2017: WINNER - KLICKLY',
#   {'entities': [(20, 30, 'revenuegrowth_flt')]}),
#  ('Fortem Technologies Closes $17.8M in Funding Round to Scale Airspace Safety and Security Capabilities',
#   {'entities': [(37, 44, 'Funding_flt')]}),
#  ('Fortem Technologies raised $17,800,000 / Series Unknown from Alternative Investment Management and 4 other investors',
#   {'entities': [(73, 83, 'revenuegrowth_flt')]}),
#  ('eCozy raised €180,000 / Equity Crowdfunding',
#   {'entities': [(31, 43, 'Startups_flt')]}),
#  ('eCozy raised $50,000 / Product Crowdfunding',
#   {'entities': [(31, 43, 'Startups_flt')]}),
#  ('First Tellurium raised $986,600 / Post Ipo Equity',
#   {'entities': [(39, 42, 'Funding_flt')]}),
#  ('First Tellurium raised $404,000 / Post Ipo Equity',
#   {'entities': [(39, 42, 'Funding_flt')]}),
#  ('EA Adds Social Game Studio For Hardcore Players With KlickNation\xa0Acquisition',
#   {'entities': [(65, 76, 'ManagementMove_flt')]}),
#  ('South African SPARK Schools Raises Series C Funding',
#   {'entities': [(44, 51, 'Funding_flt')]}),
#  ('Fate sees positive B-cell lymphoma data at #ASCO21; ImaginAb secures funding for CD8 imaging trials',
#   {'entities': [(69, 76, 'Funding_flt')]}),
#  ('NPS: Pension regulator grants licence to DSP Investment Managers to launch fund',
#   {'entities': [(45, 55, 'revenuegrowth_flt')]}),
#  ('DSP-Explorer aiming to extend data management capabilities with Claremont acquisition',
#   {'entities': [(74, 85, 'ManagementMove_flt')]}),
#  ('Muhammad Mansoor promoted at Lactalis American Group, Inc.',
#   {'entities': [(17, 25, 'Promotion_flt')]}),
#  ('Daniel Gilliam promoted at Lactalis American Group',
#   {'entities': [(15, 23, 'Promotion_flt')]}),
#  ('Naveen Arora promoted at Lactalis American Group',
#   {'entities': [(13, 21, 'Promotion_flt')]}),
#  ('Daniel Block promoted at Lactalis American Group',
#   {'entities': [(13, 21, 'Promotion_flt')]}),
#  ('CEO of Marin County’s Scansite wins North Bay Women in Business award',
#   {'entities': [(64, 69, 'Award_flt')]}),
#  ('Ohio University Announces Third Round of Layoffs',
#   {'entities': [(41, 48, 'Layoffs_flt')]}),
#  ('I-Corps@Ohio teams support innovation and create economic development',
#   {'entities': [(27, 37, 'revenuegrowth_flt')]}),
#  ('NAVYA raised €1,250,000 / Post Ipo Debt',
#   {'entities': [(31, 34, 'Funding_flt')]}),
#  ('NAVYA raised €36,000,000 / Post Ipo Debt from Negma Group',
#   {'entities': [(32, 35, 'Funding_flt')]}),
#  ('Navya Listed as a Key Autonomous Mobility Player on the Innovation Radar Platform',
#   {'entities': [(56, 66, 'revenuegrowth_flt')]}),
#  ('S&W Expands Sorghum Breeding Effort with NexSteppe Germplasm Acquisition',
#   {'entities': [(61, 72, 'ManagementMove_flt')]}),
#  ('Vonnie Estes to Receive 2017 Rosalind Franklin Award',
#   {'entities': [(47, 52, 'Award_flt')]}),
#  ('BIO is Now Accepting Nominations for its Fourth Annual Rosalind Franklin Award',
#   {'entities': [(73, 78, 'Award_flt')]}),
#  ('Media Advisory: NexSteppe CEO Anna Rath to Receive BIO Award Honoring an Outstanding Woman in Industrial Biotechnology',
#   {'entities': [(55, 60, 'Award_flt')]}),
#  ("AgFunder's New Report Captures $2.36B In AgTech Investment in 2014 - AgFunderNews",
#   {'entities': [(48, 58, 'revenuegrowth_flt')]}),
#  ('Ensuredit raised ₹330,000,000 / Seed from 9Unicorns Accelerator Fund and 5 other investors',
#   {'entities': [(52, 63, 'Startups_flt')]}),
#  ('New Report Finds Domestic Payments Organisations Increase Innovation During Covid-19',
#   {'entities': [(58, 68, 'revenuegrowth_flt')]}),
#  ("PriceSmart, Inc. Just Recorded A 86% EPS Beat: Here's What Analysts Are Forecasting Next",
#   {'entities': [(37, 40, 'Earningsreport_flt')]}),
#  ('Compute North’s Reorganization Plan Approved by Bankruptcy Judge',
#   {'entities': [(16, 30, 'ManagementMove_flt')]}),
#  ('Sanity Group closed a $44.2M Series A financing round with new investment led by Redalpine.',
#   {'entities': [(63, 73, 'revenuegrowth_flt')]}),
#  ('4Front raised $5,800,000 / Post Ipo Debt from Navy Capital',
#   {'entities': [(32, 35, 'Funding_flt')]}),
#  ('Cloud Brokerage and Marketplace Platform',
#   {'entities': [(6, 15, 'IPO_flt')]}),
#  ('Cloud World Forum Award Winners Highlight World Class Cloud Solutions',
#   {'entities': [(18, 23, 'Award_flt')]}),
#  ('Top 5 books to give startup enthusiasts these Christmas holidays',
#   {'entities': [(20, 27, 'Startups_flt')]}),
#  ('Top 5 books to give startup enthusiasts these Christmas holidays',
#   {'entities': [(20, 27, 'Startups_flt')]}),
#  ('D.C. Archbishop Faces Criticism and Calls for Resignation After Pennsylvania Report on Priest Sex Abuse',
#   {'entities': [(46, 57, 'ManagementMove_flt')]}),
#  ('KB associates secures Investment from ECI Partners',
#   {'entities': [(22, 32, 'revenuegrowth_flt')]}),
#  ('dSPACE and Cepton Partner to Provide 3D Lidar Simulation for ADAS and Autonomous Applications',
#   {'entities': [(81, 93, 'Openpositions_flt')]}),
#  ('Carousell mulling US listing via SPAC merger at US$1.5B valuation: report',
#   {'entities': [(38, 44, 'ManagementMove_flt')]}),
#  ('ECPI University Receives SC Cyber Award for Excellence',
#   {'entities': [(34, 39, 'Award_flt')]}),
#  ('Announcing Significant Strategic Investment from TPG',
#   {'entities': [(33, 43, 'revenuegrowth_flt')]}),
#  ('InMobi Co-founder Piyush Shah on building India’s first unicorn',
#   {'entities': [(56, 63, 'Startups_flt')]}),
#  ('Musiversal Raises €1.36M in Seed Funding',
#   {'entities': [(33, 40, 'Funding_flt')]}),
#  ('Music production platform Musiversal raises €1.3m in growth funding round',
#   {'entities': [(60, 67, 'Funding_flt')]}),
#  ('Startup Weekend Johor Bahru 2015', {'entities': [(0, 7, 'Startups_flt')]}),
#  ('45 startups in Asia that caught our eye',
#   {'entities': [(3, 11, 'Startups_flt')]}),
#  ('Ticketing platform Peatix bags US$5M in Series B funding',
#   {'entities': [(49, 56, 'Funding_flt')]}),
#  ('Ticketing Platform Peatix Announces US$5 Million in Series B Funding to Fuel Growth and Innovation',
#   {'entities': [(61, 68, 'Funding_flt')]}),
#  ('Turkish music startup Musixen raises $2m funding round',
#   {'entities': [(14, 21, 'Startups_flt')]}),
#  ('Musk Juror Calls Investor Case Against Tesla CEO ‘Disorganized’',
#   {'entities': [(17, 25, 'Funding_flt')]}),
#  ('Elon Musk is changing Twitter so much, even investor Marc Andreessen is getting upset and complained to him directly',
#   {'entities': [(44, 52, 'Funding_flt')]}),
#  ('AIIM completes follow-on acquisition of MetroFibre',
#   {'entities': [(25, 36, 'ManagementMove_flt')]}),
#  ('AIIM becomes MetroFibre’s largest shareholder',
#   {'entities': [(34, 45, 'IPO_flt')]}),
#  ("Rocketstart's First Class of Startups Goes To Silicon Valley",
#   {'entities': [(29, 37, 'Startups_flt')]}),
#  ('France gives startups tax breaks. And now plans to take them\xa0back.',
#   {'entities': [(13, 21, 'Startups_flt')]}),
#  ('MXP4 Raises $4 Million Funding For Its Interactive Music Widgets',
#   {'entities': [(23, 30, 'Funding_flt')]}),
#  ('Innovation Eases The Friction Of Global Payment Rails',
#   {'entities': [(0, 10, 'revenuegrowth_flt')]}),
#  ('How Governments Navigate ACH Payments Innovation',
#   {'entities': [(38, 48, 'revenuegrowth_flt')]}),
#  ("Abu Dhabi's KBBO Group to expand investment in education",
#   {'entities': [(33, 43, 'revenuegrowth_flt')]}),
#  ('Renewal Mill Launches Equity Crowdfunding Campaign to Raise $1M',
#   {'entities': [(29, 41, 'Startups_flt')]}),
#  ('Indian tech startup 114 AI Innovation bags UK-US space contract',
#   {'entities': [(12, 19, 'Startups_flt')]}),
#  ('Administrate scales up with £3.78m investment',
#   {'entities': [(35, 45, 'revenuegrowth_flt')]}),
#  ('Edinburgh start-up strikes deal with Silicon Valley cloud tech firm',
#   {'entities': [(10, 18, 'Startups_flt')]}),
#  ('Administrate first Scottish tech startup at Beirut Digital District',
#   {'entities': [(33, 40, 'Startups_flt')]}),
#  ('ACL Inclusive Pipeline Challenge Competition Finalists Describe Plans to Increase Hiring of Workers with Disabilities',
#   {'entities': [(82, 88, 'ManagementMove_flt')]}),
#  ('AI inside raised ¥34,800,000 / funding round from Recomm',
#   {'entities': [(31, 38, 'Funding_flt')]}),
#  ("Evaluating The Safety Of FactSet Research Systems's Dividend",
#   {'entities': [(52, 60, 'revenuegrowth_flt')]}),
#  ("FactSet Research Systems Inc. Just Recorded A 18% EPS Beat: Here's What Analysts Are Forecasting Next",
#   {'entities': [(50, 53, 'Earningsreport_flt')]}),
#  ('BOI completes the acquisition of KBC portfolios',
#   {'entities': [(18, 29, 'ManagementMove_flt')]}),
#  ('Lactiga raised $350,000 / Grant from Innovation Factory (Canada) and NJEDA',
#   {'entities': [(37, 47, 'revenuegrowth_flt')]}),
#  ('Lactiga raised CA$5,000 / Grant from Unnamed Investor',
#   {'entities': [(45, 53, 'Funding_flt')]}),
#  ('Checkmate Capital Group Completes Seed Investment in Lactiga, Inc.',
#   {'entities': [(39, 49, 'revenuegrowth_flt')]}),
#  ('HappyMongo launches the very first AI Innovation Lab for Students across India',
#   {'entities': [(38, 48, 'revenuegrowth_flt')]}),
#  ('Futo raised $15,000 / Equity Crowdfunding',
#   {'entities': [(29, 41, 'Startups_flt')]}),
#  ('Forterra raised $500,000,000 / Post Ipo Debt',
#   {'entities': [(36, 39, 'Funding_flt')]}),
#  ('Swiss investment management firm Partners Group buys Forterro, a provider of resource planning software and services for SMBs, from Battery Ventures for €1B',
#   {'entities': [(6, 16, 'revenuegrowth_flt')]}),
#  ('Forterro Gains Investor in Partners Group',
#   {'entities': [(15, 23, 'Funding_flt')]}),
#  ('BSE IPO index hits new high; Gland Pharma, MTAR zoom over 40% in a month',
#   {'entities': [(4, 7, 'Funding_flt')]}),
#  ('Polycare raised an undisclosed amount / Non Equity Assistance from The Circulars Accelerator',
#   {'entities': [(81, 92, 'Startups_flt')]}),
#  ('Polycarbin Raises $2M in Seed Funding',
#   {'entities': [(30, 37, 'Funding_flt')]}),
#  ('Senior US Navy officials in Japan fired after one was found drunk, naked and wandering in the woods',
#   {'entities': [(34, 39, 'LeftCompany_flt')]}),
#  ('106 Startups Who Received Investment from the C.I.A. + Most Frequent In-Q-Tel Co-Investors',
#   {'entities': [(4, 12, 'Startups_flt')]}),
#  ('Visible Technologies Gets Funding To Help The CIA Monitor Social Media',
#   {'entities': [(26, 33, 'Funding_flt')]}),
#  ('Virtual Worlds Tech Firm ProtonMedia Raises $2.5 Million Funding',
#   {'entities': [(57, 64, 'Funding_flt')]}),
#  ('DSP Investment Managers to acquire 10% stake in Equitas Small Finance Bank',
#   {'entities': [(4, 14, 'revenuegrowth_flt')]}),
#  ("Economy likely to see cyclical upturn, says DSP Investment Managers' Sambre",
#   {'entities': [(48, 58, 'revenuegrowth_flt')]}),
#  ('PicPay files for USD 100 mln US IPO',
#   {'entities': [(32, 35, 'Funding_flt')]}),
#  ('MindDay, a startup with impact in mind',
#   {'entities': [(11, 18, 'Startups_flt')]}),
#  ('KBC Bank Ireland to stop new business applications in July',
#   {'entities': [(38, 50, 'Openpositions_flt')]}),
#  ('With $1M Investment, Intimates Startup Mindd Eyes New Categories',
#   {'entities': [(31, 38, 'Startups_flt')]}),
#  ...]

# %%
TRAIN_SET = TRAIN_DATA

# %%
# Training the Model 

import spacy
import random
from tqdm import tqdm
from spacy.training.example import Example
import time
from multiprocessing import Pool
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore", message="[W030]")
import sys

# Split TRAIN_DATA into training and validation sets
train_data, validation_data = train_test_split(TRAIN_DATA, test_size=0.2, random_state=42)

# Add labels from your existing model
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        nlp.get_pipe("ner").add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    best_loss = float('inf')  # Initialize a variable to track the best loss
    best_model = None  # Initialize a variable to store the best model
    n_iter = 1000  # Set the number of training iterations
    start_time = time.time()  # Record the start time

    def train_text(text_annotation):
        text, annotations = text_annotation
        example = Example.from_dict(nlp.make_doc(text), annotations)
        losses = {}
        nlp.update([example], drop=0.5, losses=losses)
        return losses

    consecutive_no_improvement = 0  # Initialize a counter for consecutive epochs with no improvement
    early_stopping_patience = 10  # Define the patience (number of epochs with no improvement before stopping)

    training_logs = []  # Initialize a list to store training logs

    # Redirect stdout to a log file
    log_file = open("training_ind_model.txt", "w")
    sys.stdout = log_file

    with Pool() as pool:  # Use multiprocessing for faster training
        for itn in range(n_iter):
            random.shuffle(train_data)  # Shuffle the training data

            # Training
            loss_results = list(tqdm(pool.imap(train_text, train_data), total=len(train_data)))
            total_loss = sum(loss['ner'] for loss in loss_results)
            average_loss = total_loss / len(train_data)

            # Validation
            validation_loss_results = list(tqdm(pool.imap(train_text, validation_data), total=len(validation_data)))
            validation_total_loss = sum(loss['ner'] for loss in validation_loss_results)
            validation_average_loss = validation_total_loss / len(validation_data)

            end_time = time.time()  # Record the end time
            time_taken = end_time - start_time  # Calculate the time taken for this iteration

            if validation_average_loss < best_loss:
                best_loss = validation_average_loss
                best_model = nlp.to_bytes()  # Save the best model
                consecutive_no_improvement = 0  # Reset the counter
                log = f"Iteration {itn + 1}: Best training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                training_logs.append(log)
                print(log)
            else:
                consecutive_no_improvement += 1

                if consecutive_no_improvement >= early_stopping_patience:
                    log = f"Early stopping at iteration {itn + 1}: Validation loss has not improved for {early_stopping_patience} consecutive epochs."
                    training_logs.append(log)
                    print(log)
                    break
                else:
                    log = f"Iteration {itn + 1}: Training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                    training_logs.append(log)
                    print(log)

    # Save the training logs to a file
    with open("training_main_model.txt", "w") as log_file:
        for log in training_logs:
            log_file.write(log + "\n")

    # Save the best model to disk
    nlp.to_disk("archive/updated_Main_py")

    # Close the log file and reset stdout
    log_file.close()
    sys.stdout = sys.__stdout__

print("Training completed with early stopping.")

# %%
# !jupyter nbconvert --to python main_train.ipynb
# Out:
# [NbConvertApp] Converting notebook main_train.ipynb to python
# [NbConvertApp] Writing 13690 bytes to main_train.py

# %%
nlp.to_disk("archive/updated_Main_py")
