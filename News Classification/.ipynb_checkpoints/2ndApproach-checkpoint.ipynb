# %% [markdown]
# ### Training Department Model

# %% [markdown]
# /New Models/DepartmentNew/

# %%
# !python3 -m spacy download en_core_web_md
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-md==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.6.0/en_core_web_md-3.6.0-py3-none-any.whl (42.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 11.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /home/azureuser/.local/lib/python3.10/site-packages (from en-core-web-md==3.6.0) (3.6.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.0.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.10.11)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.0.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (59.6.0)
# Requirement already satisfied: packaging>=20.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/azureuser/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /home/azureuser/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/azureuser/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /home/azureuser/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/azureuser/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/azureuser/.local/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (0.1.0)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-md==3.6.0) (8.0.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import spacy
import pymongo

import spacy

# Load the spaCy English language model
nlp = spacy.load('en_core_web_md')
nlp = spacy.blank('en')
ner = nlp.create_pipe('ner')
nlp.add_pipe('ner', last=True)

# Connect to the MongoDB server
client = pymongo.MongoClient("mongodb://Aditya:123456@20.25.72.14:27017/?authMechanism=DEFAULT&authSource=admin")

# Choose the 'news' database
db = client['news']

# Choose the 'news_set' collection
collection = db['news_set']

# Query all data and exclude the _id field
query_result = collection.find({}, {"_id": 0})

# Initialize an empty list to store the data
data_list = []

# Loop through the query result and append each document to the list
for item in query_result:
    data_list.append(item)

# Print the number of documents retrieved
print(f"Retrieved {len(data_list)} documents from 'news_set' collection")

# Close the MongoDB connection
client.close()

import ast

department_train = []

# Open the text file
with open('15sept5000data.txt', 'r') as file:
    # Read each line in the file
    for line in file:
        # Parse the line as a dictionary
        data = ast.literal_eval(line)
        
        # Extract the necessary information
        headline = data['headline']
        department = data['department']
        department_keyword = data['department_keyword']
        
        # Find the start and end indices of the department keyword in the headline
        start_index = headline.find(department_keyword)
        end_index = start_index + len(department_keyword)
        
        # Append the information to the department_train list
        department_train.append((headline, {'entities': [(start_index, end_index, department)]}))

# Print the department_train list
print(department_train[:5]) , len(department_train)

# Training the Model 


import spacy
import random
from tqdm import tqdm
from spacy.training.example import Example
import time
from multiprocessing import Pool
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore", message="[W030]")
import sys

# Split department_train into training and validation sets
train_data, validation_data = train_test_split(department_train, test_size=0.2, random_state=42)

# Add labels from your existing model
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        nlp.get_pipe("ner").add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    best_loss = float('inf')  # Initialize a variable to track the best loss
    best_model = None  # Initialize a variable to store the best model
    n_iter = 1000  # Set the number of training iterations
    start_time = time.time()  # Record the start time

    def train_text(text_annotation):
        text, annotations = text_annotation
        example = Example.from_dict(nlp.make_doc(text), annotations)
        losses = {}
        nlp.update([example], drop=0.5, losses=losses)
        return losses

    consecutive_no_improvement = 0  # Initialize a counter for consecutive epochs with no improvement
    early_stopping_patience = 6  # Define the patience (number of epochs with no improvement before stopping)

    training_logs = []  # Initialize a list to store training logs

    # Redirect stdout to a log file
    log_file = open("2ndApproach_Dept.txt", "w")
    sys.stdout = log_file

    with Pool() as pool:  # Use multiprocessing for faster training
        for itn in range(n_iter):
            random.shuffle(train_data)  # Shuffle the training data

            # Training
            loss_results = list(tqdm(pool.imap(train_text, train_data), total=len(train_data)))
            total_loss = sum(loss['ner'] for loss in loss_results)
            average_loss = total_loss / len(train_data)

            # Validation
            validation_loss_results = list(tqdm(pool.imap(train_text, validation_data), total=len(validation_data)))
            validation_total_loss = sum(loss['ner'] for loss in validation_loss_results)
            validation_average_loss = validation_total_loss / len(validation_data)

            end_time = time.time()  # Record the end time
            time_taken = end_time - start_time  # Calculate the time taken for this iteration

            if validation_average_loss < best_loss:
                best_loss = validation_average_loss
                best_model = nlp.to_bytes()  # Save the best model
                consecutive_no_improvement = 0  # Reset the counter
                log = f"Iteration {itn + 1}: Best training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                training_logs.append(log)
                print(log)
            else:
                consecutive_no_improvement += 1

                if consecutive_no_improvement >= early_stopping_patience:
                    log = f"Early stopping at iteration {itn + 1}: Validation loss has not improved for {early_stopping_patience} consecutive epochs."
                    training_logs.append(log)
                    print(log)
                    break
                else:
                    log = f"Iteration {itn + 1}: Training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                    training_logs.append(log)
                    print(log)

    # Save the training logs to a file
    with open("2ndApproach_Dept.txt", "w") as log_file:
        for log in training_logs:
            log_file.write(log + "\n")

    # Save the best model to disk
    nlp.to_disk("archive/New Models/DepartmentNew")

    # Close the log file and reset stdout
    log_file.close()
    sys.stdout = sys.__stdout__

print("Training completed with early stopping.")
# Out:
# Retrieved 725555 documents from 'news_set' collection
# [('PickleJar Launches New Ticketing Platform Milestone and Expands Service to Include Fan Experiences Within the App', {'entities': [(10, 18, 'Product Management')]}), ('PickleJar Debuts New Campaign to Spotlight the Return of Live Music', {'entities': [(33, 42, 'Marketing')]}), ('Entertainment Payments Platform PickleJar Thrives With Artist-First Focus', {'entities': [(55, 67, 'Marketing')]}), ('First Responder Technologies raised $74,655 / Debt Financing', {'entities': [(51, 60, 'Finance')]}), ('Making Internet of Things even smarter is the focus on Morrisville firm Device Solutions', {'entities': [(72, 78, 'Engineering')]})]
#   0%|                                                                                                                                                      | 1/9519 [00:00<53:24,  2.97it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "A Researcher’s Guide to Some" with entities "[(-1, 11, 'Research')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Orlen VC objął emisję akcji spółki ICsec" with entities "[(-1, 5, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   0%|▋                                                                                                                                                    | 47/9519 [00:01<03:02, 51.79it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PickNik Robotics Lands Space Force, NASA Deal for ..." with entities "[(8, 13, 'Engineering')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   1%|█▋                                                                                                                                                  | 107/9519 [00:02<02:59, 52.50it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Inside InLights' industrial real estate plans" with entities "[(-1, 10, 'Real Estate')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   2%|██▍                                                                                                                                                 | 159/9519 [00:03<02:29, 62.53it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Winning numbers drawn in 'Play3 Day' game" with entities "[(-1, 2, 'Others')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   3%|████▌                                                                                                                                               | 297/9519 [00:05<02:32, 60.50it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AI新創技轉成功 台科大教授王靖維推出AIHPC平台" with entities "[(9, 17, 'Engineering')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   5%|███████▏                                                                                                                                            | 461/9519 [00:08<02:32, 59.55it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Meet United States’s 32 Top CEO’s in the Ad Target..." with entities "[(-1, 4, 'Leadership')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   5%|███████▎                                                                                                                                            | 468/9519 [00:08<03:05, 48.71it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Announcing Telecom Council’s Innovation Showcase C..." with entities "[(-1, 16, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   5%|███████▍                                                                                                                                            | 477/9519 [00:08<02:39, 56.64it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PickUp Coffee raised an undisclosed amount / Pre S..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   6%|████████▎                                                                                                                                           | 537/9519 [00:09<02:27, 60.91it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AIDS Healthcare Foundation buys Fort Lauderdale ho..." with entities "[(-1, 4, 'HospitalityTourismResturants')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   6%|████████▉                                                                                                                                           | 572/9519 [00:10<02:42, 55.11it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MINCO SILVER CORPORATION STARTS INITIAL EXPLORATIO..." with entities "[(-1, 10, 'Mining')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   8%|███████████▉                                                                                                                                        | 764/9519 [00:13<02:47, 52.32it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Iran building advanced weapons site in east Syria ..." with entities "[(-1, 7, 'MilitaryandProtectiveService')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   9%|█████████████                                                                                                                                       | 840/9519 [00:15<02:29, 58.09it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AIDP’s Andy Khawaja is “The Man Behind Limitless N..." with entities "[(0, 2, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   9%|█████████████▋                                                                                                                                      | 878/9519 [00:15<02:40, 53.69it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PsiQuantum and QunaSys Partner to Advance Industri..." with entities "[(3, 10, 'Research')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   9%|█████████████▉                                                                                                                                      | 895/9519 [00:16<02:36, 55.03it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MINCO CAPITAL ANNOUNCES COMMENCEMENT OF NORMAL COU..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  11%|███████████████▊                                                                                                                                   | 1020/9519 [00:18<02:26, 57.84it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Institutions urged to follow UCC in investment ple..." with entities "[(-1, 9, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  11%|████████████████▎                                                                                                                                  | 1059/9519 [00:19<02:37, 53.63it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AIkido Pharma Confirms Receipt of Unsolicited Offe..." with entities "[(14, 21, 'Legal')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  11%|████████████████▍                                                                                                                                  | 1065/9519 [00:19<02:50, 49.55it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fuss: 三年轻人创建网站 随时预约钟点女佣" with entities "[(21, 23, 'Hospitality Tourism Resturants')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  12%|██████████████████                                                                                                                                 | 1166/9519 [00:21<02:27, 56.66it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Andrew Forrest’s Minderoo Foundation backs $5.4 mi..." with entities "[(37, 41, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  14%|████████████████████▏                                                                                                                              | 1310/9519 [00:23<02:14, 61.25it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Medtronic’s billion-dollar buying spree" with entities "[(-1, 10, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  14%|████████████████████▎                                                                                                                              | 1317/9519 [00:23<02:13, 61.64it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "YFM Equity Partners acquired Images At Work Limite..." with entities "[(-1, 7, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  14%|████████████████████▉                                                                                                                              | 1353/9519 [00:24<02:16, 60.00it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Accel-KKR acquired Navtor for an undisclosed amoun..." with entities "[(-1, 7, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  14%|█████████████████████                                                                                                                              | 1367/9519 [00:24<02:13, 61.07it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AIDP and Andy Khawaja are Using AI Technology for ..." with entities "[(0, 2, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  15%|█████████████████████▋                                                                                                                             | 1403/9519 [00:25<02:22, 56.80it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Helbiz takes over MiMoto Smart Mobility for e-mope..." with entities "[(-1, 7, 'BusinessDevelopment')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  15%|██████████████████████▊                                                                                                                            | 1474/9519 [00:26<02:22, 56.64it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fusionware raised an undisclosed amount / funding ..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  16%|███████████████████████                                                                                                                            | 1492/9519 [00:26<02:14, 59.87it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "MIDAS SHARE TIPS: A perfect building block to ceme..." with entities "[(96, 103, 'Operations')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  17%|████████████████████████▌                                                                                                                          | 1594/9519 [00:28<02:23, 55.14it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Alcoa 1Q profit tops forecasts despite lower alumi..." with entities "[(-1, 7, 'Operations')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  17%|████████████████████████▉                                                                                                                          | 1614/9519 [00:28<02:17, 57.48it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "l’acn l’accessorio Nucleare S.r.l. raised €50,000 ..." with entities "[(19, 26, 'Engineering')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  17%|█████████████████████████▌                                                                                                                         | 1654/9519 [00:29<02:16, 57.77it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "How Disney Upgrades The Haunted Mansion to Scare N..." with entities "[(-1, 5, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  17%|█████████████████████████▋                                                                                                                         | 1662/9519 [00:29<02:07, 61.80it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "高速、精準、快速建模 AIExplore讓AI系統建置不再遙遠" with entities "[(11, 20, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  18%|█████████████████████████▊                                                                                                                         | 1669/9519 [00:29<02:41, 48.71it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Preempt Security raises $8 mln Series A funding" with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  18%|██████████████████████████                                                                                                                         | 1690/9519 [00:30<02:20, 55.53it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Peas&Love, Agripolis, Sous les Fraises… quand les ..." with entities "[(-1, 7, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  18%|██████████████████████████▉                                                                                                                        | 1748/9519 [00:31<02:14, 57.57it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Oncopeptides starts commercialization of Pepaxti i..." with entities "[(-1, 16, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  19%|███████████████████████████▊                                                                                                                       | 1801/9519 [00:32<02:18, 55.68it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monk’s Hill leads $2m round of Malaysian proptech ..." with entities "[(-1, 10, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  20%|█████████████████████████████▏                                                                                                                     | 1893/9519 [00:33<02:18, 55.15it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Mind Behind the “World Computer”: Ethereum’s V..." with entities "[(-1, 9, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Orange deploys private 5G net to support LACROIX’s..." with entities "[(7, 13, 'Engineering')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  21%|██████████████████████████████▊                                                                                                                    | 1993/9519 [00:35<02:10, 57.88it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Imágenes Graciosas (imageneshumor)" with entities "[(-1, 7, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  21%|███████████████████████████████▌                                                                                                                   | 2044/9519 [00:36<02:02, 61.19it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Updated: Mobile Avatar Firm Pulse Gets $7 Million ..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  22%|███████████████████████████████▊                                                                                                                   | 2057/9519 [00:36<02:12, 56.14it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Monk’s Hill Ventures leads $8.1m round of Indonesi..." with entities "[(-1, 19, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  23%|█████████████████████████████████▍                                                                                                                 | 2162/9519 [00:38<02:11, 55.86it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Team OHEL Wins for OHEL’s Children in NYC Marathon" with entities "[(-1, 14, 'Community and SocialServices')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  23%|██████████████████████████████████                                                                                                                 | 2203/9519 [00:39<02:08, 57.01it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Winning numbers drawn in 'Play4 Day' game" with entities "[(-1, 2, 'Others')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  24%|██████████████████████████████████▋                                                                                                                | 2244/9519 [00:39<02:19, 52.22it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The Dish: Restaurant manager trades business suit ..." with entities "[(-1, 5, 'Hospitality Tourism Resturants')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  25%|████████████████████████████████████                                                                                                               | 2337/9519 [00:41<01:52, 64.02it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Music Traveler: Services for musicians worldwide" with entities "[(-1, 7, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  25%|████████████████████████████████████▋                                                                                                              | 2374/9519 [00:42<02:25, 48.99it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Celebration of world cinema - 2nd Pondicherry Inte..." with entities "[(-1, 5, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  25%|████████████████████████████████████▊                                                                                                              | 2382/9519 [00:42<02:21, 50.50it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Covoiturage : Ecov double son chiffre d’affaires e..." with entities "[(-1, 9, 'Consulting')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  26%|██████████████████████████████████████                                                                                                             | 2464/9519 [00:43<02:08, 55.01it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mark Bannister named dean of the Boise State Unive..." with entities "[(-1, 3, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  26%|██████████████████████████████████████▉                                                                                                            | 2519/9519 [00:44<01:42, 68.32it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "eCourierz: Elevating the Express Courier Market wi..." with entities "[(-1, 8, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  28%|████████████████████████████████████████▋                                                                                                          | 2632/9519 [00:46<02:07, 54.00it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "188 Nomor Apa? Inilah Jawaban Penjelasannya" with entities "[(-1, 3, 'Others')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  28%|████████████████████████████████████████▊                                                                                                          | 2640/9519 [00:46<01:58, 57.97it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NAUTICAL EYE-CAPTURING ARTWORK SETS SAIL IN LYN: T..." with entities "[(-1, 6, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  31%|█████████████████████████████████████████████▍                                                                                                     | 2946/9519 [00:52<01:56, 56.65it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pear Sports adds new fitness capabilities after Pi..." with entities "[(-1, 6, 'Product Management')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Don’t have a cow: Imagindairy introduces animal-fr..." with entities "[(-1, 9, 'Product Management')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  31%|█████████████████████████████████████████████▊                                                                                                     | 2963/9519 [00:52<01:51, 58.73it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Nil Foundation raised $22,000,000 / Series Unknown..." with entities "[(-1, 8, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  31%|██████████████████████████████████████████████▏                                                                                                    | 2993/9519 [00:52<01:58, 55.15it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Able Lending Receives $100 Million To Fund Small B..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  32%|███████████████████████████████████████████████                                                                                                    | 3045/9519 [00:53<01:47, 60.42it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Court Avenue closures start Friday: What to know" with entities "[(-1, 7, 'Operations')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  33%|████████████████████████████████████████████████▌                                                                                                  | 3142/9519 [00:55<01:47, 59.34it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "OhioHealth, Columbus Oncology expand cancer center..." with entities "[(-1, 5, 'HealthCare')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  34%|██████████████████████████████████████████████████▏                                                                                                | 3251/9519 [00:57<01:44, 60.07it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Equistone-backed Adm Group makes two acquisitions" with entities "[(-1, 11, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  35%|███████████████████████████████████████████████████▎                                                                                               | 3325/9519 [00:58<01:51, 55.79it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Winning numbers drawn in 'Play3 Night' game" with entities "[(-1, 2, 'Others')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  36%|█████████████████████████████████████████████████████                                                                                              | 3435/9519 [01:00<01:38, 62.00it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mustang Seats raised $9,200,000 / Series Unknown" with entities "[(-1, 5, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  37%|██████████████████████████████████████████████████████▏                                                                                            | 3507/9519 [01:01<01:40, 59.95it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Pollo Campero Announces Opening of New Restaurant ..." with entities "[(-1, 8, 'Hospitality Tourism Resturants')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  37%|██████████████████████████████████████████████████████▉                                                                                            | 3557/9519 [01:02<01:52, 53.19it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "智慧醫療影像大進展 AI將扮演醫師超級眼睛" with entities "[(2, 4, 'HealthCare')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  38%|███████████████████████████████████████████████████████▏                                                                                           | 3572/9519 [01:03<02:00, 49.42it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NavTrac raised $500,000 / Pre Seed from FoundersX ..." with entities "[(-1, 5, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  38%|███████████████████████████████████████████████████████▋                                                                                           | 3606/9519 [01:03<01:38, 59.95it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "ADMA Stock: Why It Fell Today" with entities "[(-1, 3, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  38%|███████████████████████████████████████████████████████▊                                                                                           | 3613/9519 [01:03<01:40, 58.80it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Green energy entrepreneur Dale Vince's Ecotricity ..." with entities "[(-1, 15, 'Entrepreneurship')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  39%|█████████████████████████████████████████████████████████▏                                                                                         | 3707/9519 [01:05<01:39, 58.69it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Next Act Theatre names first managing director sin..." with entities "[(-1, 16, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  39%|█████████████████████████████████████████████████████████▊                                                                                         | 3744/9519 [01:06<01:42, 56.47it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Computer Age Management Services acquires majority..." with entities "[(-1, 7, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  40%|██████████████████████████████████████████████████████████▌                                                                                        | 3794/9519 [01:06<01:33, 61.11it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Picky raised $1,320,000 / Pre Seed from Klim Ventu..." with entities "[(-1, 8, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  40%|███████████████████████████████████████████████████████████                                                                                        | 3824/9519 [01:07<01:45, 54.07it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "DS Investment Management Co.,Ltd: 옐로모바일 '피키캐스트', D..." with entities "[(61, 63, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  41%|███████████████████████████████████████████████████████████▋                                                                                       | 3869/9519 [01:08<01:29, 63.27it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PARENTING: Picky eating has been given a new name:..." with entities "[(-1, 8, 'HealthCare')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  41%|███████████████████████████████████████████████████████████▉                                                                                       | 3882/9519 [01:08<01:49, 51.60it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "‘Wasteland’ Director’s New Blockchain Gaming Store..." with entities "[(-1, 9, 'ProductManagement')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  41%|████████████████████████████████████████████████████████████▋                                                                                      | 3932/9519 [01:09<01:39, 55.89it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Minds raised an undisclosed amount / Series B from..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  41%|████████████████████████████████████████████████████████████▊                                                                                      | 3938/9519 [01:09<01:58, 46.98it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Musk’s Twitter Has Just 180,000 U.S. Subscribers, ..." with entities "[(-1, 5, 'Leadership')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  43%|██████████████████████████████████████████████████████████████▌                                                                                    | 4052/9519 [01:11<01:38, 55.58it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Mind Over Matter, With a Machine’s Help" with entities "[(-1, 8, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  43%|██████████████████████████████████████████████████████████████▊                                                                                    | 4064/9519 [01:11<01:45, 51.87it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cordia announces public tender offer for all remai..." with entities "[(-1, 18, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  43%|██████████████████████████████████████████████████████████████▊                                                                                    | 4071/9519 [01:11<01:40, 53.95it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Imaginary Ventures raised a new fund: Imaginary Ve..." with entities "[(10, 17, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  44%|████████████████████████████████████████████████████████████████▋                                                                                  | 4187/9519 [01:13<01:34, 56.63it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "COUPLE DANCE CHOREOGRAPHER NEAR ME | Beats On Feet" with entities "[(-1, 12, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  44%|████████████████████████████████████████████████████████████████▉                                                                                  | 4201/9519 [01:14<01:36, 54.99it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The 10 Biggest Rounds Of July: Xpansiv Locks In To..." with entities "[(-1, 5, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  45%|█████████████████████████████████████████████████████████████████▌                                                                                 | 4245/9519 [01:15<01:39, 53.13it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Let AI run your next marketing campaign: Metadata...." with entities "[(-1, 8, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  45%|█████████████████████████████████████████████████████████████████▊                                                                                 | 4264/9519 [01:15<01:46, 49.29it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Adlib Software Announces Appointment of Helen Rose..." with entities "[(-1, 2, 'Leadership')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...
#   warnings.warn(
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████            | 8746/9519 [02:49<00:14, 53.66it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Cómo La Cosmopolitana está manejando la Nueva Norm..." with entities "[(-1, 8, 'Leadership')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍          | 8837/9519 [02:51<00:12, 55.23it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Fuss: 三年轻人创建网站 随时预约钟点女佣" with entities "[(21, 23, 'Hospitality Tourism Resturants')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  93%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎         | 8890/9519 [02:52<00:12, 52.41it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "YFM Equity Partners acquired Images At Work Limite..." with entities "[(-1, 7, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊      | 9115/9519 [02:56<00:08, 50.38it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Antenna raised $10,149,985 / Series A from BDMI an..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌     | 9165/9519 [02:57<00:07, 47.70it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HK plant-based provider bags $70m from TPG-backed ..." with entities "[(-1, 6, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  97%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 9271/9519 [02:59<00:04, 52.39it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Third Frontier awards more than $9 million in fund..." with entities "[(-1, 6, 'Research')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 9305/9519 [03:00<00:03, 56.95it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "PickNik Robotics Lands Space Force, NASA Deal for ..." with entities "[(8, 13, 'Engineering')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 9323/9519 [03:00<00:03, 50.41it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "GeekWire Radio: Microsoft’s Satya Nadella looks ah..." with entities "[(-1, 10, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "How To Get A Ladder In Animal Crossing: New Horizo..." with entities "[(-1, 5, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████  | 9394/9519 [03:02<00:02, 49.20it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Equistone-backed Adm Group makes two acquisitions" with entities "[(-1, 11, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 9502/9519 [03:04<00:00, 57.46it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Team OHEL Wins for OHEL’s Children in NYC Marathon" with entities "[(-1, 14, 'Community and SocialServices')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊| 9510/9519 [03:04<00:00, 61.08it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Aier Eye Hospital Group acquired Clinica Baviera f..." with entities "[(-1, 7, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 9519/9519 [03:04<00:00, 51.63it/s]
#   6%|█████████▏                                                                                                                                          | 147/2380 [00:02<00:46, 47.74it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I monopattini di Helbiz verso il Nasdaq, chiusa l’..." with entities "[(50, 62, 'Business Development')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#   9%|█████████████▉                                                                                                                                      | 225/2380 [00:04<00:44, 48.11it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "The beginner’s guide to semantic search: Examples ..." with entities "[(-1, 7, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  10%|██████████████▊                                                                                                                                     | 239/2380 [00:04<00:38, 55.61it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "第二屆「E-Mobility Global Demo Day」新創競賽決選名單出爐 多國新創將於20..." with entities "[(33, 35, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  10%|███████████████▏                                                                                                                                    | 245/2380 [00:04<00:39, 54.54it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "How Driver’s License Points Work, and How Much The..." with entities "[(-1, 15, 'Legal')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  12%|██████████████████▎                                                                                                                                 | 294/2380 [00:05<00:41, 50.33it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Thimbleweed Park is an old-school adventure game j..." with entities "[(-1, 8, 'Arts and Design')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  21%|██████████████████████████████▌                                                                                                                     | 492/2380 [00:09<00:42, 44.18it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "CIWare Makes Proactive BI Sociable" with entities "[(-1, 5, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  22%|████████████████████████████████▉                                                                                                                   | 530/2380 [00:10<00:32, 56.26it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Scotland’s cyber awards" with entities "[(-1, 9, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  23%|██████████████████████████████████▌                                                                                                                 | 556/2380 [00:10<00:35, 51.92it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "와디즈, DS투자자문으로부터 10억원 투자 유치" with entities "[(5, 11, 'Finance')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  26%|██████████████████████████████████████▊                                                                                                             | 624/2380 [00:12<00:34, 51.04it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Sunday's regional sports roundup: Hampton Roads Wa..." with entities "[(-1, 5, 'Sports')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  30%|████████████████████████████████████████████▍                                                                                                       | 715/2380 [00:14<00:35, 47.55it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "NextAdvisor’s Beginner’s Guide to Points and Miles" with entities "[(-1, 12, 'Marketing')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  35%|████████████████████████████████████████████████████▎                                                                                               | 841/2380 [00:16<00:28, 53.11it/s]/home/azureuser/.local/lib/python3.10/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "AppArchitect Lets Anyone Build iOS Apps, No Coding..." with entities "[(-1, 5, 'IT')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
#  45%|██████████████████████████████████████████████████████████████████                                                                                 | 1069/2380 [00:21<00:25, 50.58it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.10/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 119
#     116 average_loss = total_loss / len(train_data)
#     118 # Validation
# --> 119 validation_loss_results = list(tqdm(pool.imap(train_text, validation_data), total=len(validation_data)))
#     120 validation_total_loss = sum(loss['ner'] for loss in validation_loss_results)
#     121 validation_average_loss = validation_total_loss / len(validation_data)
#
# File ~/.local/lib/python3.10/site-packages/tqdm/std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File /usr/lib/python3.10/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Industry Model

# %%
import spacy
import pymongo


# Load the spaCy English language model
nlp = spacy.load('en_core_web_md')
nlp = spacy.blank('en')
ner = nlp.create_pipe('ner')
nlp.add_pipe('ner', last=True)

# Connect to the MongoDB server
client = pymongo.MongoClient("mongodb://Aditya:123456@20.25.72.14:27017/?authMechanism=DEFAULT&authSource=admin")

# Choose the 'news' database
db = client['news']

# Choose the 'news_set' collection
collection = db['news_set']

# Query all data and exclude the _id field
query_result = collection.find({}, {"_id": 0})

# Initialize an empty list to store the data
data_list = []

# Loop through the query result and append each document to the list
for item in query_result:
    data_list.append(item)

# Print the number of documents retrieved
print(f"Retrieved {len(data_list)} documents from 'news_set' collection")

# Close the MongoDB connection
client.close()

import ast

industry_train = []

# Open the text file
with open('15sept5000data.txt', 'r') as file:
    # Read each line in the file
    for line in file:
        # Parse the line as a dictionary
        data = ast.literal_eval(line)
        
        # Extract the necessary information
        headline = data['headline']
        industry = data['industry']
        industry_keyword = data['industry_keyword']
        
        # Find the start and end indices of the industry keyword in the headline
        start_index = headline.find(industry_keyword)
        end_index = start_index + len(industry_keyword)
        
        # Append the information to the industry_train list
        industry_train.append((headline, {'entities': [(start_index, end_index, industry)]}))

# Print the industry_train list
print(industry_train[:5]) , len(industry_train)

import spacy
import random
from tqdm import tqdm
from spacy.training.example import Example
import time
from multiprocessing import Pool
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore", message="[W030]")
import sys

# Split industry_train into training and validation sets
train_data, validation_data = train_test_split(industry_train, test_size=0.2, random_state=42)

# Add labels from your existing model
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        nlp.get_pipe("ner").add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    best_loss = float('inf')  # Initialize a variable to track the best loss
    best_model = None  # Initialize a variable to store the best model
    n_iter = 1000  # Set the number of training iterations
    start_time = time.time()  # Record the start time

    def train_text(text_annotation):
        text, annotations = text_annotation
        example = Example.from_dict(nlp.make_doc(text), annotations)
        losses = {}
        nlp.update([example], drop=0.5, losses=losses)
        return losses

    consecutive_no_improvement = 0  # Initialize a counter for consecutive epochs with no improvement
    early_stopping_patience = 6  # Define the patience (number of epochs with no improvement before stopping)

    training_logs = []  # Initialize a list to store training logs

    # Redirect stdout to a log file
    log_file = open("2ndApproach_Ind.txt", "w")
    sys.stdout = log_file

    with Pool() as pool:  # Use multiprocessing for faster training
        for itn in range(n_iter):
            random.shuffle(train_data)  # Shuffle the training data

            # Training
            loss_results = list(tqdm(pool.imap(train_text, train_data), total=len(train_data)))
            total_loss = sum(loss['ner'] for loss in loss_results)
            average_loss = total_loss / len(train_data)

            # Validation
            validation_loss_results = list(tqdm(pool.imap(train_text, validation_data), total=len(validation_data)))
            validation_total_loss = sum(loss['ner'] for loss in validation_loss_results)
            validation_average_loss = validation_total_loss / len(validation_data)

            end_time = time.time()  # Record the end time
            time_taken = end_time - start_time  # Calculate the time taken for this iteration

            if validation_average_loss < best_loss:
                best_loss = validation_average_loss
                best_model = nlp.to_bytes()  # Save the best model
                consecutive_no_improvement = 0  # Reset the counter
                log = f"Iteration {itn + 1}: Best training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                training_logs.append(log)
                print(log)
            else:
                consecutive_no_improvement += 1

                if consecutive_no_improvement >= early_stopping_patience:
                    log = f"Early stopping at iteration {itn + 1}: Validation loss has not improved for {early_stopping_patience} consecutive epochs."
                    training_logs.append(log)
                    print(log)
                    break
                else:
                    log = f"Iteration {itn + 1}: Training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                    training_logs.append(log)
                    print(log)

    # Save the training logs to a file
    with open("2ndApproach_Ind.txt", "w") as log_file:
        for log in training_logs:
            log_file.write(log + "\n")

    # Save the best model to disk
    nlp.to_disk("archive/New Models/IndustryNew")

    # Close the log file and reset stdout
    log_file.close()
    sys.stdout = sys.__stdout__

print("Training completed with early stopping.")

# %% [markdown]
# ### Key Words Model

# %%
import spacy
import pymongo


# Load the spaCy English language model
nlp = spacy.load('en_core_web_md')
nlp = spacy.blank('en')
ner = nlp.create_pipe('ner')
nlp.add_pipe('ner', last=True)


# Connect to the MongoDB server
client = pymongo.MongoClient("mongodb://Aditya:123456@20.25.72.14:27017/?authMechanism=DEFAULT&authSource=admin")

# Choose the 'news' database
db = client['news']

# Choose the 'news_set' collection
collection = db['news_set']

# Query all data and exclude the _id field
query_result = collection.find({}, {"_id": 0})

# Initialize an empty list to store the data
data_list = []

# Loop through the query result and append each document to the list
for item in query_result:
    data_list.append(item)

# Print the number of documents retrieved
print(f"Retrieved {len(data_list)} documents from 'news_set' collection")

# Close the MongoDB connection
client.close()

import ast
key_events_train = []

# Open the text file
with open('15sept5000data.txt', 'r') as file:
    # Read each line in the file
    for line in file:
        # Parse the line as a dictionary
        data = ast.literal_eval(line)
        
        # Extract the necessary information
        headline = data['headline']
        key_events = data['key_events']
        
        # Check if 'key_events_keywords' is in data
        if 'key_events_keywords' in data:
            key_events_keyword = data['key_events_keywords']
            
            # Check if key_events_keyword is not None and not a list
            if key_events_keyword is not None and not isinstance(key_events_keyword, list):
                # Find the start and end indices of the key_events keyword in the headline
                start_index = headline.find(key_events_keyword)
                end_index = start_index + len(key_events_keyword)
                
                # Append the information to the key_events_train list
                key_events_train.append((headline, {'entities': [(start_index, end_index, key_events)]}))

# Print the key_events_train list
print(key_events_train[:5]) , len(key_events_train)

# Training the Model 

import spacy
import random
from tqdm import tqdm
from spacy.training.example import Example
import time
from multiprocessing import Pool
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore", message="[W030]")
import sys

# Split key_events_train into training and validation sets
train_data, validation_data = train_test_split(key_events_train, test_size=0.2, random_state=42)

# Add labels from your existing model
for _, annotations in train_data:
    for ent in annotations.get('entities'):
        nlp.get_pipe("ner").add_label(ent[2])

other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.begin_training()
    best_loss = float('inf')  # Initialize a variable to track the best loss
    best_model = None  # Initialize a variable to store the best model
    n_iter = 1000  # Set the number of training iterations
    start_time = time.time()  # Record the start time

    def train_text(text_annotation):
        text, annotations = text_annotation
        example = Example.from_dict(nlp.make_doc(text), annotations)
        losses = {}
        nlp.update([example], drop=0.5, losses=losses)
        return losses

    consecutive_no_improvement = 0  # Initialize a counter for consecutive epochs with no improvement
    early_stopping_patience = 6  # Define the patience (number of epochs with no improvement before stopping)

    training_logs = []  # Initialize a list to store training logs

    # Redirect stdout to a log file
    log_file = open("2ndApproach_Key.txt", "w")
    sys.stdout = log_file

    with Pool() as pool:  # Use multiprocessing for faster training
        for itn in range(n_iter):
            random.shuffle(train_data)  # Shuffle the training data

            # Training
            loss_results = list(tqdm(pool.imap(train_text, train_data), total=len(train_data)))
            total_loss = sum(loss['ner'] for loss in loss_results)
            average_loss = total_loss / len(train_data)

            # Validation
            validation_loss_results = list(tqdm(pool.imap(train_text, validation_data), total=len(validation_data)))
            validation_total_loss = sum(loss['ner'] for loss in validation_loss_results)
            validation_average_loss = validation_total_loss / len(validation_data)

            end_time = time.time()  # Record the end time
            time_taken = end_time - start_time  # Calculate the time taken for this iteration

            if validation_average_loss < best_loss:
                best_loss = validation_average_loss
                best_model = nlp.to_bytes()  # Save the best model
                consecutive_no_improvement = 0  # Reset the counter
                log = f"Iteration {itn + 1}: Best training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                training_logs.append(log)
                print(log)
            else:
                consecutive_no_improvement += 1

                if consecutive_no_improvement >= early_stopping_patience:
                    log = f"Early stopping at iteration {itn + 1}: Validation loss has not improved for {early_stopping_patience} consecutive epochs."
                    training_logs.append(log)
                    print(log)
                    break
                else:
                    log = f"Iteration {itn + 1}: Training loss: {average_loss:.4f}, Validation loss: {validation_average_loss:.4f}, Time taken: {time_taken:.2f} seconds"
                    training_logs.append(log)
                    print(log)

    # Save the training logs to a file
    with open("2ndApproach_Key.txt", "w") as log_file:
        for log in training_logs:
            log_file.write(log + "\n")

    # Save the best model to disk
    nlp.to_disk("archive/New Models/KeyEventsNew")

    # Close the log file and reset stdout
    log_file.close()
    sys.stdout = sys.__stdout__

print("Training completed with early stopping.")
